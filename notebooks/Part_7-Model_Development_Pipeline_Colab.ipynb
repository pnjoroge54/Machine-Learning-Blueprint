# %% [markdown]
# <a href="https://colab.research.google.com/github/pnjoroge54/Machine-Learning-Blueprint/blob/streamlined/notebooks/Part_7-Model_Development_Pipeline_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Setup and Dependencies

# %%
# !pip install -q condacolab
# import condacolab
# condacolab.install_from_url("https://repo.anaconda.com/miniconda/Miniconda3-py310_23.1.0-1-Linux-x86_64.sh")
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# ✨🍰✨ Everything looks OK!

# %%
# --- Colab Setup ---
# === CONFIGURATION ===
GITHUB_USER = "pnjoroge54"
REPO_NAME = "Machine-Learning-Blueprint"
BRANCH = "streamlined"  # or 'master' or any other branch
TOKEN = None     # Set to your GitHub token if repo is private

# === CLONE REPO ===
import os
from pathlib import Path

if TOKEN:
    repo_url = f"https://{TOKEN}@github.com/{GITHUB_USER}/{REPO_NAME}.git"
else:
    repo_url = f"https://github.com/{GITHUB_USER}/{REPO_NAME}.git"

# !git clone --branch {BRANCH} {repo_url}
os.chdir(REPO_NAME)

# === ADD TO PYTHON PATH ===
import sys
sys.path.append(Path.cwd())

repo_path = Path.cwd() / REPO_NAME

# === OPTIONAL: VERIFY STRUCTURE ===
# !ls -R | head -20  # Show top-level files/folders

# --- Environment Diagnostics ---
from pathlib import Path
print(f"Working Dir: {Path.cwd()}")

# from google.colab import drive
# drive.mount('/content/drive')

print("Setup complete. You can now run your imports.")
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Cloning into 'Machine-Learning-Blueprint'...
# remote: Enumerating objects: 2923, done.
# remote: Counting objects: 100% (627/627), done.
# remote: Compressing objects: 100% (422/422), done.
# remote: Total 2923 (delta 344), reused 370 (delta 205), pack-reused 2296 (from 1)
# Receiving objects: 100% (2923/2923), 10.13 MiB | 7.81 MiB/s, done.
# Resolving deltas: 100% (1831/1831), done.
# Filtering content: 100% (11/11), 270.17 MiB | 44.32 MiB/s, done.
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# .:
# afml
# CODE_OF_CONDUCT.md
# CONTRIBUTING.md
# coverage
# data
# environment.yml
# LICENSE.txt
# MANIFEST.in
# MQL5
# notebooks
# performance_attribution.py
# pylint
# pyproject.toml
# README.md
# requirements.txt
# setup.cfg
# setup.py
# testing_tuning
# tools
# Working Dir: /content/Machine-Learning-Blueprint
# Setup complete. You can now run your imports.

# %%
# !pip install feature_engine loguru ruptures appdirs dask fastparquet TA-Lib pandas-ta mplfinance deap
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Requirement already satisfied: feature_engine in /usr/local/lib/python3.10/site-packages (1.9.3)
# Requirement already satisfied: loguru in /usr/local/lib/python3.10/site-packages (0.7.3)
# Requirement already satisfied: ruptures in /usr/local/lib/python3.10/site-packages (1.1.10)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.10/site-packages (1.4.4)
# Requirement already satisfied: dask in /usr/local/lib/python3.10/site-packages (2026.1.2)
# Requirement already satisfied: fastparquet in /usr/local/lib/python3.10/site-packages (2025.12.0)
# Requirement already satisfied: TA-Lib in /usr/local/lib/python3.10/site-packages (0.6.8)
# ERROR: Ignored the following versions that require a different python version: 0.4.67b0 Requires-Python >=3.12; 0.4.71b0 Requires-Python >=3.12
# ERROR: Could not find a version that satisfies the requirement pandas-ta (from versions: none)
# ERROR: No matching distribution found for pandas-ta

# %%
from loguru import logger
from tqdm import tqdm

# Define a sink that uses tqdm.write
def tqdm_sink(msg):
    tqdm.write(msg, end="")  # end="" avoids double newlines

# Remove default handler and add our custom one
logger.remove()
logger.add(
    tqdm_sink,
    format="<green>{time:YYYY-MM-DD HH:mm:ss:ms}</green> | "
           "<level>{level: <8}</level> | "
           "<cyan>{name}</cyan>:<cyan>{function}</cyan>:<cyan>{line}</cyan> - "
           "<level>{message}</level>",
    colorize=True
)
# Out:
# 1

# %%
import re
import time
import warnings
# import winsound
from pathlib import Path
from pprint import pformat, pprint

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.base import clone
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    accuracy_score,
    f1_score,
    log_loss,
    precision_score,
    recall_score,
)
from tqdm import tqdm

from afml.cross_validation import (
    PurgedKFold,
    PurgedSplit,
    analyze_cross_val_scores,
    analyze_cross_val_scores_calibrated,
    probability_weighted_accuracy,
)
from afml.data_structures.bars import *
from afml.ensemble import (
    SequentiallyBootstrappedBaggingClassifier,
    compute_custom_oob_metrics,
    estimate_ensemble_size,
)
from afml.labeling.triple_barrier import (
    add_vertical_barrier,
    get_event_weights,
    triple_barrier_labels,
)
# from afml.production.model_development import (
#     calculate_rolling_metrics,
#     create_feature_engineering_pipeline,
#     generate_events_triple_barrier,
#     load_and_prepare_training_data,
# )
from afml.sample_weights.optimized_attribution import (
    get_weights_by_time_decay_optimized,
)
from afml.strategies import (
    BollingerStrategy,
    create_bollinger_features,
    get_entries,
)
from afml.util.volatility import get_daily_vol
from afml.util.misc import dict_to_key, expand_params, value_counts_data

warnings.filterwarnings("ignore")
# plt.style.use("seaborn-v0_8-whitegrid")
plt.style.use("dark_background")
# Out:
# 2026-02-02 16:15:23:1523 | WARNING  | afml.cache.mlflow_integration:<module>:23 - MLflow not available - install with: pip install mlflow
# 2026-02-02 16:15:23:1523 | DEBUG    | afml.cache:<module>:684 - Enhanced cache features available:
# 2026-02-02 16:15:23:1523 | DEBUG    | afml.cache:<module>:685 -   - Unified cacheable() decorator with auto_versioning
# 2026-02-02 16:15:23:1523 | DEBUG    | afml.cache:<module>:686 -   - Robust cache keys for NumPy/Pandas
# 2026-02-02 16:15:23:1523 | DEBUG    | afml.cache:<module>:687 -   - MLflow integration: ✓
# 2026-02-02 16:15:23:1523 | DEBUG    | afml.cache:<module>:688 -   - Backtest caching: ✓
# 2026-02-02 16:15:23:1523 | DEBUG    | afml.cache:<module>:689 -   - Cache monitoring: ✓
# 2026-02-02 16:15:23:1523 | DEBUG    | afml.cache:<module>:690 -   - Orphaned cache cleanup: ✓
# 2026-02-02 16:15:23:1523 | DEBUG    | afml.cache:<module>:691 -   - Orphaned cache cleanup: ✓
# 2026-02-02 16:15:23:1523 | DEBUG    | afml.cache:<module>:692 -   - Cache size info and selective clearing: ✓
# 2026-02-02 16:15:23:1523 | DEBUG    | afml.cache:_configure_numba:59 - Numba cache configured: /root/.cache/afml/numba_cache
# 2026-02-02 16:15:23:1523 | INFO     | afml.cache:initialize_cache_system:245 - AFML cache system initialized:
# 2026-02-02 16:15:23:1523 | INFO     | afml.cache:initialize_cache_system:246 -   Joblib cache: /root/.cache/afml/joblib_cache
# 2026-02-02 16:15:23:1523 | INFO     | afml.cache:initialize_cache_system:247 -   Numba cache: /root/.cache/afml/numba_cache
# 2026-02-02 16:15:27:1527 | WARNING  | afml:<module>:130 - Some lightweight modules failed to import: No module named 'onnx'
# 2026-02-02 16:15:27:1527 | INFO     | afml:<module>:368 - AFML v1.0.0 ready - 10 heavy modules available for lazy loading
# 2026-02-02 16:15:27:1527 | DEBUG    | afml:<module>:373 - Cache status: Hit rate: 0.0% | Tracked functions: 0 | Heavy modules loaded: 0
# 2026-02-02 16:15:27:1527 | DEBUG    | afml:<module>:377 - ✓ Cache monitoring available
# 2026-02-02 16:15:27:1527 | DEBUG    | afml:<module>:379 - ✓ MLflow integration available
# 2026-02-02 16:15:27:1527 | DEBUG    | afml:<module>:381 - ✓ Backtest caching available
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipython-input-4276099660.py in <cell line: 0>()
#      20 from tqdm import tqdm
#      21
# ---> 22 from afml.cross_validation import (
#      23     PurgedKFold,
#      24     PurgedSplit,
#
# /content/Machine-Learning-Blueprint/afml/cross_validation/__init__.py in <module>
#       6                              precision_score, recall_score)
#       7
# ----> 8 from .combinatorial import CombinatorialPurgedKFold
#       9 from .cross_validation import (PurgedKFold, PurgedSplit, PurgedWalkForwardCV,
#      10                                analyze_cross_val_scores, ml_cross_val_score,
#
# /content/Machine-Learning-Blueprint/afml/cross_validation/combinatorial.py in <module>
#       2 import numpy as np
#       3 import pandas as pd
# ----> 4 from sklearn.base import BaseCrossValidator
#       5 from itertools import combinations
#       6
#
# ImportError: cannot import name 'BaseCrossValidator' from 'sklearn.base' (/usr/local/lib/python3.12/dist-packages/sklearn/base.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# from afml.cache import clear_data_access_log, clear_afml_cache


# clear_afml_cache()
# clear_data_access_log()

# %% [markdown]
# ## 0. Data Collection and Cleaning

# %%
symbol = "EURUSD"
start_date = "2022-01-01"
end_date = "2023-12-31"
account_name = "FUNDEDNEXT_STLR2_6K"
bar_type = "time"
bar_size = "M5"
price = "mid_price"

# %%
# df = load_and_prepare_training_data(
#     symbol,
#     start_date,
#     end_date,
#     account_name,
#     bar_type,
#     bar_size,
#     price,
# )
df = pd.read_parquet()
df.info()
# Out:
# 2025-12-16 11:14:06.234 | DEBUG    | afml.cache.unified_cache_system:track_cache_call:574 - Cache HIT: afml.production.model_development.load_and_prepare_training_data (key: c09c4258...)
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 147860 entries, 2022-01-03 00:05:00 to 2023-12-29 23:00:00
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   open         147860 non-null  float32
#  1   high         147860 non-null  float32
#  2   low          147860 non-null  float32
#  3   close        147860 non-null  float32
#  4   spread       147860 non-null  float32
#  5   spread_bps   147860 non-null  float32
#  6   tick_volume  147860 non-null  int16
#  7   tick_num     147860 non-null  int32
# dtypes: float32(6), int16(1), int32(1)
# memory usage: 5.4 MB

# %% [markdown]
# ## 1. Bollinger Band Strategy

# %% [markdown]
# ### Time-Bars

# %%
from scipy.stats import randint, uniform

feature_configs = dict(bb_period=np.arange(5, 35, 2), bb_std=np.arange(1.5, 2.1, 0.1))

data_configs = dict(
    account_name=[account_name],
    bar_type=["time", "tick"],
    bar_size=["M1"],
    price=["mid_price"],
)
pt_sl_ = np.arange(0.5, 2.5, 0.5)
label_configs = dict(
    target_lookback=[3, 5, 7, 10, 20, 30, 50, 100],
    profit_target=[1],
    stop_loss=[2],
    max_holding_period=[
        dict(days=1),
        dict(days=2),
        dict(days=3),
        dict(days=5),
    ],  # dict(num_bars=100),
    min_ret=[0],
    vertical_barrier_zero=[True],
)

# %% [markdown]
# #### Model Params

# %%
clf = RandomForestClassifier(
    criterion="entropy",
    class_weight="balanced_subsample",
    random_state=42,
)
name = "clf"
param_grid = {
    f"{name}__n_estimators": randint(50, 500),  # sample integers between 100 and 500
    f"{name}__max_depth": randint(3, 7),  # sample integers between 3 and 6
    f"{name}__min_samples_split": randint(2, 20),
    f"{name}__min_samples_leaf": randint(1, 10),
    f"{name}__max_features": uniform(0.1, 0.9),
    f"{name}__min_weight_fraction_leaf": uniform(0.05, 0.45),
}

# %%
model_params = dict(
    pipe_clf=clf,
    param_grid=param_grid,
    cv_splits=5,
    bagging_n_estimators=0,
    bagging_max_samples=1,
    bagging_max_features=1,
    rnd_search_iter=20,
    n_jobs=-1,
    pct_embargo=0.01,
    random_state=42,
    verbose=False,
)

# %% [markdown]
# #### Develop Production Model

# %%
from collections import namedtuple

from afml.production.model_development import ModelDevelopmentPipeline

data_config = expand_params(data_configs)[0]

# feature_cfg = expand_params(feature_config)[0]
feature_config = {
    "func": create_bollinger_features,
    "params": dict(window=10, std=1.5),
}

label_config = dict(
    target_lookback=10,
    profit_target=1,
    stop_loss=2,
    max_holding_period=dict(days=1),
    min_ret=0,
    vertical_barrier_zero=True,
    filter_as_series=False,
)

strategy = BollingerStrategy(**feature_config["params"])
strategy_cfg = label_config.copy()
strategy_cfg["strategy"] = strategy.get_strategy_name()


train_start = start_date
train_end = end_date
training_cfg = dict(train_start=train_start, train_end=train_end)

# %%
# pipeline = ModelDevelopmentPipeline(
#     symbol=symbol,
#     train_start=train_start,
#     train_end=train_end,
#     strategy=strategy,
#     data_config=data_config,
#     feature_config=feature_config,
#     label_config=label_config,
#     model_params=model_params,
# )
# best_model, model_features, metrics, config = pipeline.run()

# %%
trained_models = {}

# %%
TrainedModel = namedtuple(
    "TrainedModel", ["model", "model_features", "metrics", "config", "pipeline"]
)
keyify = dict_to_key()

for data_config in expand_params(data_configs):
    training_cfg.update(data_config)
    outer_key = keyify(training_cfg)
    inner_key = keyify(strategy_cfg)
    trained_models.setdefault(outer_key, {})
    trained_models.setdefault(inner_key, {})
    if not trained_models[outer_key].get(inner_key):
        pipeline = ModelDevelopmentPipeline(
            symbol=symbol,
            train_start=train_start,
            train_end=train_end,
            strategy=strategy,
            data_config=data_config,
            feature_config=feature_config,
            label_config=label_config,
            model_params=model_params,
        )

        best_model, model_features, metrics, config = pipeline.run()
        trained_models[outer_key][inner_key] = TrainedModel(
            best_model, model_features, metrics, config, pipeline
        )

winsound.Beep(1000, 1000)
# Out:
# 2025-12-16 11:14:08 | afml.production.model_development | INFO | Starting pipeline for EURUSD
# 2025-12-16 11:14:08 | afml.production.model_development | INFO | Training period: 2022-01-01 to 2023-12-31
# 2025-12-16 11:14:08 | afml.production.model_development | INFO | Output directory: Models\Bollinger_w10_std1_5\EURUSD\FUNDEDNEXT_STLR2_6K\time\M1\20220101_20231231\bdad004f
#
# ======================================================================
# PRODUCTION MODEL DEVELOPMENT PIPELINE
# ======================================================================
#
# Configuration
# --------------------------------------------------
# strategy                 Bollinger_w10_std1.5
# symbol                                 EURUSD
# training_start                     2022-01-01
# training_end                       2023-12-31
# account_name              FUNDEDNEXT_STLR2_6K
# bar_type                                 time
# bar_size                                   M1
# price                               mid_price
# target_lookback                            10
# profit_target                               1
# stop_loss                                   2
# max_holding_period                {'days': 1}
# min_ret                                     0
# vertical_barrier_zero                    True
# filter_as_series                        False
# 2025-12-16 11:14:09 [info     ] pipeline_step                  status=started step=pipeline_start strategy=Bollinger_w10_std1.5 symbol=EURUSD train_period=2022-01-01_2023-12-31
#
# [Step 1/7] Loading training data...
# 2025-12-16 11:14:09 | afml.cache.unified_cache_system | DEBUG | Cache HIT: afml.production.model_development.load_and_prepare_training_data (key: d890725d...)
# 2025-12-16 11:14:09 [info     ] pipeline_step                  duration_seconds=0.10399937629699707 metrics={'samples': 738824} status=completed step=data_loading
# ✓ Loaded 738,824 samples
#
# [Step 2/7] Computing features...
# 2025-12-16 11:14:09 | afml.cache.unified_cache_system | DEBUG | Cache HIT: afml.production.model_development.create_feature_engineering_pipeline (key: 4e32ea77...)
# 2025-12-16 11:14:09 [info     ] pipeline_step                  duration_seconds=0.699995756149292 metrics={'features_generated': 68} status=completed step=feature_engineering
# ✓ Generated 68 features
#
# [Step 3/7] Generating events...
# 2025-12-16 11:14:09 | afml.cache.unified_cache_system | DEBUG | Cache HIT: afml.production.model_development.generate_events_triple_barrier (key: 5a7b1eb0...)
# 2025-12-16 11:14:09 [info     ] pipeline_step                  duration_seconds=0.14899849891662598 metrics={'events_generated': 75975, 'label_distribution':       count  proportion
# bin
# 1    49,791     0.65536
# 0    26,184     0.34464, 'average_uniqueness': 0.4667911271632548} status=completed step=label_generation
# ✓ Generated events:
#       count  proportion
# bin
# 1    49,791     0.65536
# 0    26,184     0.34464
#
# Average Uniqueness: 0.4668
#
# [Step 4/7] Computing sample weights...
# 2025-12-16 11:18:04 | afml.production.model_development | INFO | Best Weighting Scheme: Uniqueness Exp 0.05808
# 2025-12-16 11:18:07 | afml.cache.unified_cache_system | DEBUG | Cache MISS: afml.production.model_development.find_optimal_sample_weight (key: 9d10ce42...) (00:03:57)
# 2025-12-16 11:18:07 [info     ] pipeline_step                  duration_seconds=237.31548690795898 metrics={'weighting_scheme': 'uniqueness_exp_0.05808361216819946', 'weight_cv_score': 0.7457131539000748} status=completed step=weight_computation
# ✓ Best weighting scheme: uniqueness_exp_0.05808361216819946
#
# [Step 5/7] Computing rolling meta-label features...
# 2025-12-16 11:18:07 | afml.cache.unified_cache_system | DEBUG | Cache HIT: afml.production.model_development.calculate_rolling_metrics (key: ae8cdce2...)
# 2025-12-16 11:18:20 [info     ] pipeline_step                  duration_seconds=13.350001573562622 metrics={'meta_features_added': 8, 'features_after_preprocessing': 72, 'features_removed': -4} status=completed step=meta_features_preprocessing
# ✓ Computed rolling meta-label features
# ✓ Preprocessed features: 72 features retained
#
# [Step 6/7] Training model with cross-validation...
# 2025-12-16 11:18:21 | afml.cache.unified_cache_system | DEBUG | Cache HIT: afml.cross_validation.hyper_fit.clf_hyper_fit_internal (key: 907bd2af...)
# 2025-12-16 11:18:21 [info     ] pipeline_step                  duration_seconds=0.4719998836517334 metrics={'cv_score': 0.6915768921130778, 'best_params': {'clf__max_depth': 6, 'clf__max_features': 0.12075618253727419, 'clf__min_samples_leaf': 3, 'clf__min_samples_split': 13, 'clf__min_weight_fraction_leaf': 0.28140549728612524, 'clf__n_estimators': 369}, 'n_splits': 5} status=completed step=model_training
# ✓ Best CV score: 0.6916
# ✓ Best params: {'clf__max_depth': 6, 'clf__max_features': 0.12075618253727419, 'clf__min_samples_leaf': 3, 'clf__min_samples_split': 13, 'clf__min_weight_fraction_leaf': 0.28140549728612524, 'clf__n_estimators': 369}
#
# [Step 7/7] Analyzing feature importance...
# 2025-12-16 11:18:21 [info     ] pipeline_step                  duration_seconds=0.1509995460510254 metrics={'top_feature': 'rolling_accuracy_20'} status=completed step=feature_analysis
#
# Top 10 Features:
#             feature  importance
# rolling_accuracy_20    0.166330
#       rolling_f1_20    0.132372
# rolling_accuracy_50    0.131260
#       rolling_f1_50    0.109463
#              spread    0.029035
#              d1_vol    0.025773
#         hour_cos_h2    0.022493
#         ret_1_lag_1    0.022391
#    parkinson_vol_10    0.019278
#  london_session_vol    0.018018
#
#
# [Generating Reports] Creating analysis reports...
# 🔍 Running hyperparameter analysis...
# ================================================================================
# HYPERPARAMETER ANALYSIS REPORT
# ================================================================================
#
# 1. TOP PERFORMING MODELS (sorted by mean_test_score):
# --------------------------------------------------
#                                                                                                                                                                                                        params  mean_test_score  std_test_score  mean_fit_time
# 4   {'clf__max_depth': 6, 'clf__max_features': 0.12075618253727419, 'clf__min_samples_leaf': 3, 'clf__min_samples_split': 13, 'clf__min_weight_fraction_leaf': 0.28140549728612524, 'clf__n_estimators': 369}         0.691577        0.011027      28.989994
# 2    {'clf__max_depth': 4, 'clf__max_features': 0.15077042112439024, 'clf__min_samples_leaf': 8, 'clf__min_samples_split': 13, 'clf__min_weight_fraction_leaf': 0.4723487190570876, 'clf__n_estimators': 435}         0.683852        0.011899      28.105996
# 6    {'clf__max_depth': 4, 'clf__max_features': 0.9539969835279999, 'clf__min_samples_leaf': 2, 'clf__min_samples_split': 10, 'clf__min_weight_fraction_leaf': 0.05718481349909639, 'clf__n_estimators': 435}         0.677322        0.006976     614.569299
# 17    {'clf__max_depth': 4, 'clf__max_features': 0.8984914683186939, 'clf__min_samples_leaf': 1, 'clf__min_samples_split': 4, 'clf__min_weight_fraction_leaf': 0.10381741067223577, 'clf__n_estimators': 180}         0.675696        0.006911     175.406800
# 1     {'clf__max_depth': 5, 'clf__max_features': 0.5133240027692805, 'clf__min_samples_leaf': 5, 'clf__min_samples_split': 5, 'clf__min_weight_fraction_leaf': 0.11429006806487335, 'clf__n_estimators': 180}         0.670490        0.007110      95.500397
# 5     {'clf__max_depth': 3, 'clf__max_features': 0.14180537144799796, 'clf__min_samples_leaf': 3, 'clf__min_samples_split': 8, 'clf__min_weight_fraction_leaf': 0.1267358556592812, 'clf__n_estimators': 216}         0.669676        0.009235      33.474998
# 10    {'clf__max_depth': 4, 'clf__max_features': 0.905344615384884, 'clf__min_samples_leaf': 8, 'clf__min_samples_split': 15, 'clf__min_weight_fraction_leaf': 0.13819228808861533, 'clf__n_estimators': 239}         0.669449        0.008087     196.870216
# 16    {'clf__max_depth': 4, 'clf__max_features': 0.1858691048413702, 'clf__min_samples_leaf': 7, 'clf__min_samples_split': 6, 'clf__min_weight_fraction_leaf': 0.37832278025212884, 'clf__n_estimators': 409}         0.667428        0.007923      36.593196
# 13   {'clf__max_depth': 5, 'clf__max_features': 0.4810613326357327, 'clf__min_samples_leaf': 1, 'clf__min_samples_split': 13, 'clf__min_weight_fraction_leaf': 0.18206967862311718, 'clf__n_estimators': 112}         0.664284        0.002792      40.329997
# 12   {'clf__max_depth': 3, 'clf__max_features': 0.3528410587186427, 'clf__min_samples_leaf': 9, 'clf__min_samples_split': 16, 'clf__min_weight_fraction_leaf': 0.12437012257835113, 'clf__n_estimators': 394}         0.664078        0.007689     133.290791
#
# 2. PERFORMANCE SUMMARY:
# --------------------------------------------------
# Average mean_test_score: 0.6656 ± 0.0106
# Best mean_test_score: 0.6916
# Worst mean_test_score: 0.6482
# Performance Range: 0.0434
#
# 3. STABILITY ANALYSIS:
# --------------------------------------------------
# Models with stable performance (std ≤ 0.03): 20
# Best stable model: 0.6916 ± 0.0110
#
# 4. TIME-EFFICIENCY ANALYSIS:
# --------------------------------------------------
#
# 5. HYPERPARAMETER TRENDS:
# --------------------------------------------------
#
# Parameter: clf__max_depth
# Optimal value: 4 (score: 0.6716)
# Performance by value:
#                       score_mean  score_std  count  fold_std_mean  time_mean
# param_clf__max_depth
# 4                         0.6716     0.0098      6         0.0088   184.0137
# 6                         0.6659     0.0177      4         0.0104    99.7223
# 3                         0.6638     0.0048      4         0.0088   108.2067
# 5                         0.6607     0.0073      6         0.0076    60.1069
#
# Parameter: clf__max_features
# Optimal value: 0.12075618253727419 (score: 0.6916)
# Performance by value:
#                          score_mean  score_std  count  fold_std_mean  time_mean
# param_clf__max_features
# 0.120756                     0.6916        NaN      1         0.0110    28.9900
# 0.150770                     0.6839        NaN      1         0.0119    28.1060
# 0.953997                     0.6773        NaN      1         0.0070   614.5693
# 0.898491                     0.6757        NaN      1         0.0069   175.4068
# 0.513324                     0.6705        NaN      1         0.0071    95.5004
# 0.141805                     0.6697        NaN      1         0.0092    33.4750
# 0.905345                     0.6694        NaN      1         0.0081   196.8702
# 0.185869                     0.6674        NaN      1         0.0079    36.5932
# 0.481061                     0.6643        NaN      1         0.0028    40.3300
# 0.352841                     0.6641        NaN      1         0.0077   133.2908
# 0.749557                     0.6636        NaN      1         0.0093   166.1914
# 0.316923                     0.6623        NaN      1         0.0069   119.1400
# 0.484787                     0.6620        NaN      1         0.0052    37.7866
# 0.816889                     0.6600        NaN      1         0.0078   117.2920
# 0.278958                     0.6595        NaN      1         0.0110    46.2450
# 0.860080                     0.6581        NaN      1         0.0081   132.6173
# 0.933671                     0.6579        NaN      1         0.0089    99.8698
# 0.568061                     0.6556        NaN      1         0.0112    52.5364
# 0.992990                     0.6515        NaN      1         0.0156   118.1418
# 0.918388                     0.6482        NaN      1         0.0115    23.4877
#
# Parameter: clf__min_samples_leaf
# Optimal value: 3 (score: 0.6744)
# Performance by value:
#                              score_mean  score_std  count  fold_std_mean  time_mean
# param_clf__min_samples_leaf
# 3                                0.6744     0.0153      3         0.0085    33.4172
# 5                                0.6705        NaN      1         0.0071    95.5004
# 8                                0.6682     0.0114      4         0.0097    97.1283
# 2                                0.6677     0.0136      2         0.0076   373.5933
# 7                                0.6644     0.0027      3         0.0081   107.3082
# 1                                0.6638     0.0121      3         0.0084   111.2929
# 9                                0.6610     0.0044      2         0.0083   116.5803
# 4                                0.6519     0.0052      2         0.0113    38.0120
#
# Parameter: clf__min_samples_split
# Optimal value: 10 (score: 0.6773)
# Performance by value:
#                               score_mean  score_std  count  fold_std_mean  time_mean
# param_clf__min_samples_split
# 10                                0.6773        NaN      1         0.0070   614.5693
# 13                                0.6707     0.0165      5         0.0097    66.9416
# 5                                 0.6705        NaN      1         0.0071    95.5004
# 4                                 0.6676     0.0115      2         0.0090   110.8259
# 6                                 0.6674        NaN      1         0.0079    36.5932
# 15                                0.6665     0.0041      2         0.0087   181.5308
# 8                                 0.6624     0.0051      4         0.0078    72.1058
# 16                                0.6611     0.0042      2         0.0079   132.9540
# 19                                0.6519     0.0052      2         0.0113    38.0120
#
# Parameter: clf__min_weight_fraction_leaf
# Optimal value: 0.28140549728612524 (score: 0.6916)
# Performance by value:
#                                      score_mean  score_std  count  fold_std_mean  time_mean
# param_clf__min_weight_fraction_leaf
# 0.281405                                 0.6916        NaN      1         0.0110    28.9900
# 0.472349                                 0.6839        NaN      1         0.0119    28.1060
# 0.057185                                 0.6773        NaN      1         0.0070   614.5693
# 0.103817                                 0.6757        NaN      1         0.0069   175.4068
# 0.114290                                 0.6705        NaN      1         0.0071    95.5004
# 0.126736                                 0.6697        NaN      1         0.0092    33.4750
# 0.138192                                 0.6694        NaN      1         0.0081   196.8702
# 0.378323                                 0.6674        NaN      1         0.0079    36.5932
# 0.182070                                 0.6643        NaN      1         0.0028    40.3300
# 0.124370                                 0.6641        NaN      1         0.0077   133.2908
# 0.272208                                 0.6636        NaN      1         0.0093   166.1914
# 0.272830                                 0.6623        NaN      1         0.0069   119.1400
# 0.263917                                 0.6620        NaN      1         0.0052    37.7866
# 0.250625                                 0.6600        NaN      1         0.0078   117.2920
# 0.405579                                 0.6595        NaN      1         0.0110    46.2450
# 0.422932                                 0.6581        NaN      1         0.0081   132.6173
# 0.432517                                 0.6579        NaN      1         0.0089    99.8698
# 0.398810                                 0.6556        NaN      1         0.0112    52.5364
# 0.325244                                 0.6515        NaN      1         0.0156   118.1418
# 0.348135                                 0.6482        NaN      1         0.0115    23.4877
#
# 6. CROSS-VALIDATION CONSISTENCY:
# --------------------------------------------------
# Fold performance consistency:
#   Fold 0: 0.6758 ± 0.0113
#   Fold 1: 0.6734 ± 0.0104
#   Fold 2: 0.6607 ± 0.0091
#   Fold 3: 0.6612 ± 0.0127
#   Fold 4: 0.6570 ± 0.0149
#
# 7. MODEL SELECTION RECOMMENDATION:
# --------------------------------------------------
# ✅ RECOMMENDATION: Choose stable model
#    Score: 0.6916 (vs best: 0.6916)
#    Stability: 0.0110 (vs best: 0.0110)
#    Performance difference: 0.0000 (insignificant)
#
# 🎯 RECOMMENDED HYPERPARAMETERS:
#    clf__max_depth: 6
#    clf__max_features: 0.12075618253727419
#    clf__min_samples_leaf: 3
#    clf__min_samples_split: 13
#    clf__min_weight_fraction_leaf: 0.28140549728612524
#    clf__n_estimators: 369
#
# 8. GENERATING VISUALIZATIONS...
#
# 9. PRACTICAL INTERPRETATION FOR TRADING:
# --------------------------------------------------
# Expected Strategy Performance:
#   • Best mean_test_score: 0.6916
#   • Cross-validation Consistency: Good
#
# ✅ LOW RISK: Excellent consistency across CV folds
#    Strategy likely to perform similarly in live trading
#
# ================================================================================
# ANALYSIS COMPLETE
# ================================================================================
# SPECIFIC INSIGHTS FROM YOUR RESULTS:
# ================================================================================
#
# 1. KEY OBSERVATIONS:
# --------------------------------------------------
# max_depth: 6
# min_samples_leaf: 3
# min_samples_split: 13
# n_estimators: 369
# Best Model mean_test_score: 0.6916
# Standard Deviation: 0.0110
# Training Time: 28.99s
#
# Best Simple Model (param_clf__max_depth ≤ 4):
#   param_clf__max_depth=4
#   mean_test_score: 0.6839 (vs best: 0.6916)
#
# 2. PERFORMANCE SATURATION:
# --------------------------------------------------
# Maximum performance by max_depth:
#   depth=3: 0.6697
#   depth=4: 0.6839
#   depth=5: 0.6705
#   depth=6: 0.6916
#
# 3. ACTIONABLE RECOMMENDATIONS:
# --------------------------------------------------
# ✅ Excellent performance achieved!
#    Consider testing with additional features or ensemble methods
#
# 4. PRODUCTION CONSIDERATIONS:
# --------------------------------------------------
# Expected Inference Speed: ~199.1ms per prediction
# Training Time Range: 23.49s to 614.57s
# Average Model Size: ~303 trees
# ✅ Markdown report generated: Models\Bollinger_w10_std1_5\EURUSD\FUNDEDNEXT_STLR2_6K\time\M1\20220101_20231231\bdad004f\reports\hyperparameter_analysis_report.md
# 2025-12-16 11:18:24 | afml.production.model_development | INFO | Generated hyperparameter report: Models\Bollinger_w10_std1_5\EURUSD\FUNDEDNEXT_STLR2_6K\time\M1\20220101_20231231\bdad004f\reports\hyperparameter_analysis_report.md
# 2025-12-16 11:18:25 | afml.production.model_development | INFO | Generated feature importance plot: Models\Bollinger_w10_std1_5\EURUSD\FUNDEDNEXT_STLR2_6K\time\M1\20220101_20231231\bdad004f\plots\feature_importance.png
# 2025-12-16 11:18:25 | afml.production.model_development | WARNING | HTML summary generation failed: 'numpy.ndarray' object is not callable
# ✓ Reports generated in 4.15s
#
# [Saving] Writing artifacts to disk...
# 2025-12-16 11:18:29 | afml.production.model_development | INFO | Saved all artifacts to Models\Bollinger_w10_std1_5\EURUSD\FUNDEDNEXT_STLR2_6K\time\M1\20220101_20231231\bdad004f
# ✓ Saved to Models\Bollinger_w10_std1_5\EURUSD\FUNDEDNEXT_STLR2_6K\time\M1\20220101_20231231\bdad004f
# 2025-12-16 11:18:29 [info     ] pipeline_step                  duration_seconds=260.72733187675476 metrics={'total_duration': 260.72733187675476, 'model_trained': True, 'reports_generated': True} status=completed step=pipeline_complete
#
# ✓ Pipeline completed in 00:04:21
# ======================================================================
# 2025-12-16 11:18:29 | afml.production.model_development | INFO | Starting pipeline for EURUSD
# 2025-12-16 11:18:29 | afml.production.model_development | INFO | Training period: 2022-01-01 to 2023-12-31
# 2025-12-16 11:18:29 | afml.production.model_development | INFO | Output directory: Models\Bollinger_w10_std1_5\EURUSD\FUNDEDNEXT_STLR2_6K\tick\M1\20220101_20231231\18f7d38e
#
# ======================================================================
# PRODUCTION MODEL DEVELOPMENT PIPELINE
# ======================================================================
#
# Configuration
# --------------------------------------------------
# strategy                 Bollinger_w10_std1.5
# symbol                                 EURUSD
# training_start                     2022-01-01
# training_end                       2023-12-31
# account_name              FUNDEDNEXT_STLR2_6K
# bar_type                                 tick
# bar_size                                   M1
# price                               mid_price
# target_lookback                            10
# profit_target                               1
# stop_loss                                   2
# max_holding_period                {'days': 1}
# min_ret                                     0
# vertical_barrier_zero                    True
# filter_as_series                        False
# 2025-12-16 11:18:29 [info     ] pipeline_step                  status=started step=pipeline_start strategy=Bollinger_w10_std1.5 symbol=EURUSD train_period=2022-01-01_2023-12-31
#
# [Step 1/7] Loading training data...
# 2025-12-16 11:18:29 | afml.cache.unified_cache_system | DEBUG | Cache HIT: afml.production.model_development.load_and_prepare_training_data (key: 0723057c...)
# 2025-12-16 11:18:29 [info     ] pipeline_step                  duration_seconds=0.12399840354919434 metrics={'samples': 1009134} status=completed step=data_loading
# ✓ Loaded 1,009,134 samples
#
# [Step 2/7] Computing features...
# 2025-12-16 11:18:30 | afml.cache.unified_cache_system | DEBUG | Cache HIT: afml.production.model_development.create_feature_engineering_pipeline (key: ff178d3f...)
# 2025-12-16 11:18:30 [info     ] pipeline_step                  duration_seconds=1.0159962177276611 metrics={'features_generated': 70} status=completed step=feature_engineering
# ✓ Generated 70 features
#
# [Step 3/7] Generating events...
# 2025-12-16 11:18:31 | afml.cache.unified_cache_system | DEBUG | Cache HIT: afml.production.model_development.generate_events_triple_barrier (key: 218e346f...)
# 2025-12-16 11:18:31 [info     ] pipeline_step                  duration_seconds=0.18597054481506348 metrics={'events_generated': 119330, 'label_distribution':       count  proportion
# bin
# 1    77,162    0.646627
# 0    42,168    0.353373, 'average_uniqueness': 0.48361563571210453} status=completed step=label_generation
# ✓ Generated events:
#       count  proportion
# bin
# 1    77,162    0.646627
# 0    42,168    0.353373
#
# Average Uniqueness: 0.4836
#
# [Step 4/7] Computing sample weights...
# 2025-12-16 11:24:31 | afml.production.model_development | INFO | Best Weighting Scheme: Uniqueness Linear 0.44583
# 2025-12-16 11:24:31 | afml.cache.unified_cache_system | DEBUG | Cache MISS: afml.production.model_development.find_optimal_sample_weight (key: 4c32d712...) (00:05:59)
# 2025-12-16 11:24:31 [info     ] pipeline_step                  duration_seconds=360.18627548217773 metrics={'weighting_scheme': 'uniqueness_linear_0.44583275285359114', 'weight_cv_score': 0.7437235653632116} status=completed step=weight_computation
# ✓ Best weighting scheme: uniqueness_linear_0.44583275285359114
#
# [Step 5/7] Computing rolling meta-label features...
# 2025-12-16 11:24:31 | afml.cache.unified_cache_system | DEBUG | Cache MISS: afml.production.model_development.calculate_rolling_metrics (key: 0055ebd4...) (0.15s)
# 2025-12-16 11:24:51 [info     ] pipeline_step                  duration_seconds=20.12900471687317 metrics={'meta_features_added': 8, 'features_after_preprocessing': 74, 'features_removed': -4} status=completed step=meta_features_preprocessing
# ✓ Computed rolling meta-label features
# ✓ Preprocessed features: 74 features retained
#
# [Step 6/7] Training model with cross-validation...
# 2025-12-16 13:05:24 | afml.cache.unified_cache_system | DEBUG | Cache MISS: afml.cross_validation.hyper_fit.clf_hyper_fit_internal (key: 94596468...) (01:40:33)
# 2025-12-16 13:05:24 [info     ] pipeline_step                  duration_seconds=6033.0509243011475 metrics={'cv_score': 0.6679488374320991, 'best_params': {'clf__max_depth': 4, 'clf__max_features': 0.9539969835279999, 'clf__min_samples_leaf': 2, 'clf__min_samples_split': 10, 'clf__min_weight_fraction_leaf': 0.05718481349909639, 'clf__n_estimators': 435}, 'n_splits': 5} status=completed step=model_training
# ✓ Best CV score: 0.6679
# ✓ Best params: {'clf__max_depth': 4, 'clf__max_features': 0.9539969835279999, 'clf__min_samples_leaf': 2, 'clf__min_samples_split': 10, 'clf__min_weight_fraction_leaf': 0.05718481349909639, 'clf__n_estimators': 435}
#
# [Step 7/7] Analyzing feature importance...
# 2025-12-16 13:05:24 [info     ] pipeline_step                  duration_seconds=0.37600159645080566 metrics={'top_feature': 'rolling_f1_20'} status=completed step=feature_analysis
#
# Top 10 Features:
#             feature  importance
#       rolling_f1_20    0.433746
# rolling_accuracy_20    0.401812
#              adx_14    0.094169
#              spread    0.038951
#          bbb_10_1.5    0.005250
#       month_end_vol    0.004426
#       dayofyear_cos    0.003972
#     quarter_end_vol    0.001745
#              rsi_14    0.001529
#   bb_bandwidth_diff    0.001497
#
#
# [Generating Reports] Creating analysis reports...
# 🔍 Running hyperparameter analysis...
# ================================================================================
# HYPERPARAMETER ANALYSIS REPORT
# ================================================================================
#
# 1. TOP PERFORMING MODELS (sorted by mean_test_score):
# --------------------------------------------------
#                                                                                                                                                                                                        params  mean_test_score  std_test_score  mean_fit_time
# 6    {'clf__max_depth': 4, 'clf__max_features': 0.9539969835279999, 'clf__min_samples_leaf': 2, 'clf__min_samples_split': 10, 'clf__min_weight_fraction_leaf': 0.05718481349909639, 'clf__n_estimators': 435}         0.667949        0.014576    1030.070397
# 17    {'clf__max_depth': 4, 'clf__max_features': 0.8984914683186939, 'clf__min_samples_leaf': 1, 'clf__min_samples_split': 4, 'clf__min_weight_fraction_leaf': 0.10381741067223577, 'clf__n_estimators': 180}         0.666074        0.014625     306.217198
# 2    {'clf__max_depth': 4, 'clf__max_features': 0.15077042112439024, 'clf__min_samples_leaf': 8, 'clf__min_samples_split': 13, 'clf__min_weight_fraction_leaf': 0.4723487190570876, 'clf__n_estimators': 435}         0.663562        0.029009      55.444398
# 16    {'clf__max_depth': 4, 'clf__max_features': 0.1858691048413702, 'clf__min_samples_leaf': 7, 'clf__min_samples_split': 6, 'clf__min_weight_fraction_leaf': 0.37832278025212884, 'clf__n_estimators': 409}         0.661100        0.024291      58.500797
# 4   {'clf__max_depth': 6, 'clf__max_features': 0.12075618253727419, 'clf__min_samples_leaf': 3, 'clf__min_samples_split': 13, 'clf__min_weight_fraction_leaf': 0.28140549728612524, 'clf__n_estimators': 369}         0.660993        0.024461      53.317199
# 1     {'clf__max_depth': 5, 'clf__max_features': 0.5133240027692805, 'clf__min_samples_leaf': 5, 'clf__min_samples_split': 5, 'clf__min_weight_fraction_leaf': 0.11429006806487335, 'clf__n_estimators': 180}         0.650810        0.018344     183.496200
# 10    {'clf__max_depth': 4, 'clf__max_features': 0.905344615384884, 'clf__min_samples_leaf': 8, 'clf__min_samples_split': 15, 'clf__min_weight_fraction_leaf': 0.13819228808861533, 'clf__n_estimators': 239}         0.649984        0.015965     341.671595
# 5     {'clf__max_depth': 3, 'clf__max_features': 0.14180537144799796, 'clf__min_samples_leaf': 3, 'clf__min_samples_split': 8, 'clf__min_weight_fraction_leaf': 0.1267358556592812, 'clf__n_estimators': 216}         0.645300        0.022438      60.491793
# 12   {'clf__max_depth': 3, 'clf__max_features': 0.3528410587186427, 'clf__min_samples_leaf': 9, 'clf__min_samples_split': 16, 'clf__min_weight_fraction_leaf': 0.12437012257835113, 'clf__n_estimators': 394}         0.641695        0.021350     250.619194
# 14   {'clf__max_depth': 5, 'clf__max_features': 0.27895816367992465, 'clf__min_samples_leaf': 8, 'clf__min_samples_split': 4, 'clf__min_weight_fraction_leaf': 0.40557899323904256, 'clf__n_estimators': 428}         0.638729        0.020111      82.896400
#
# 2. PERFORMANCE SUMMARY:
# --------------------------------------------------
# Average mean_test_score: 0.6434 ± 0.0138
# Best mean_test_score: 0.6679
# Worst mean_test_score: 0.6290
# Performance Range: 0.0389
#
# 3. STABILITY ANALYSIS:
# --------------------------------------------------
# Models with stable performance (std ≤ 0.03): 20
# Best stable model: 0.6679 ± 0.0146
#
# 4. TIME-EFFICIENCY ANALYSIS:
# --------------------------------------------------
#
# 5. HYPERPARAMETER TRENDS:
# --------------------------------------------------
#
# Parameter: clf__max_depth
# Optimal value: 4 (score: 0.6565)
# Performance by value:
#                       score_mean  score_std  count  fold_std_mean  time_mean
# param_clf__max_depth
# 4                         0.6565     0.0143      6         0.0193   311.4163
# 6                         0.6392     0.0150      4         0.0198   159.8923
# 5                         0.6375     0.0072      6         0.0188   108.1101
# 3                         0.6367     0.0080      4         0.0197   188.1341
#
# Parameter: clf__max_features
# Optimal value: 0.9539969835279999 (score: 0.6679)
# Performance by value:
#                          score_mean  score_std  count  fold_std_mean  time_mean
# param_clf__max_features
# 0.953997                     0.6679        NaN      1         0.0146  1030.0704
# 0.898491                     0.6661        NaN      1         0.0146   306.2172
# 0.150770                     0.6636        NaN      1         0.0290    55.4444
# 0.185869                     0.6611        NaN      1         0.0243    58.5008
# 0.120756                     0.6610        NaN      1         0.0245    53.3172
# 0.513324                     0.6508        NaN      1         0.0183   183.4962
# 0.905345                     0.6500        NaN      1         0.0160   341.6716
# 0.141805                     0.6453        NaN      1         0.0224    60.4918
# 0.352841                     0.6417        NaN      1         0.0213   250.6192
# 0.278958                     0.6387        NaN      1         0.0201    82.8964
# 0.316923                     0.6376        NaN      1         0.0210   143.2724
# 0.481061                     0.6371        NaN      1         0.0199    72.2290
# 0.484787                     0.6345        NaN      1         0.0193    63.7942
# 0.816889                     0.6340        NaN      1         0.0171   216.6116
# 0.749557                     0.6307        NaN      1         0.0181   264.3724
# 0.568061                     0.6303        NaN      1         0.0175    76.5936
# 0.918388                     0.6300        NaN      1         0.0179    29.6332
# 0.992990                     0.6294        NaN      1         0.0171   206.7998
# 0.933671                     0.6293        NaN      1         0.0171   177.0532
# 0.860080                     0.6290        NaN      1         0.0167   236.1800
#
# Parameter: clf__min_samples_leaf
# Optimal value: 5 (score: 0.6508)
# Performance by value:
#                              score_mean  score_std  count  fold_std_mean  time_mean
# param_clf__min_samples_leaf
# 5                                0.6508        NaN      1         0.0183   183.4962
# 2                                0.6485     0.0275      2         0.0156   633.1252
# 3                                0.6469     0.0133      3         0.0221    59.2011
# 8                                0.6466     0.0132      4         0.0206   174.1560
# 1                                0.6442     0.0193      3         0.0172   195.0820
# 7                                0.6431     0.0160      3         0.0211   155.3819
# 9                                0.6355     0.0088      2         0.0192   213.8362
# 4                                0.6302     0.0002      2         0.0177    53.1134
#
# Parameter: clf__min_samples_split
# Optimal value: 10 (score: 0.6679)
# Performance by value:
#                               score_mean  score_std  count  fold_std_mean  time_mean
# param_clf__min_samples_split
# 10                                0.6679        NaN      1         0.0146  1030.0704
# 6                                 0.6611        NaN      1         0.0243    58.5008
# 4                                 0.6524     0.0193      2         0.0174   194.5568
# 5                                 0.6508        NaN      1         0.0183   183.4962
# 13                                0.6457     0.0155      5         0.0223   106.2126
# 15                                0.6403     0.0137      2         0.0170   303.0220
# 8                                 0.6358     0.0068      4         0.0190   129.4877
# 16                                0.6354     0.0090      2         0.0190   243.3996
# 19                                0.6302     0.0002      2         0.0177    53.1134
#
# Parameter: clf__min_weight_fraction_leaf
# Optimal value: 0.05718481349909639 (score: 0.6679)
# Performance by value:
#                                      score_mean  score_std  count  fold_std_mean  time_mean
# param_clf__min_weight_fraction_leaf
# 0.057185                                 0.6679        NaN      1         0.0146  1030.0704
# 0.103817                                 0.6661        NaN      1         0.0146   306.2172
# 0.472349                                 0.6636        NaN      1         0.0290    55.4444
# 0.378323                                 0.6611        NaN      1         0.0243    58.5008
# 0.281405                                 0.6610        NaN      1         0.0245    53.3172
# 0.114290                                 0.6508        NaN      1         0.0183   183.4962
# 0.138192                                 0.6500        NaN      1         0.0160   341.6716
# 0.126736                                 0.6453        NaN      1         0.0224    60.4918
# 0.124370                                 0.6417        NaN      1         0.0213   250.6192
# 0.405579                                 0.6387        NaN      1         0.0201    82.8964
# 0.272830                                 0.6376        NaN      1         0.0210   143.2724
# 0.182070                                 0.6371        NaN      1         0.0199    72.2290
# 0.263917                                 0.6345        NaN      1         0.0193    63.7942
# 0.250625                                 0.6340        NaN      1         0.0171   216.6116
# 0.272208                                 0.6307        NaN      1         0.0181   264.3724
# 0.398810                                 0.6303        NaN      1         0.0175    76.5936
# 0.348135                                 0.6300        NaN      1         0.0179    29.6332
# 0.325244                                 0.6294        NaN      1         0.0171   206.7998
# 0.432517                                 0.6293        NaN      1         0.0171   177.0532
# 0.422932                                 0.6290        NaN      1         0.0167   236.1800
#
# 6. CROSS-VALIDATION CONSISTENCY:
# --------------------------------------------------
# Fold performance consistency:
#   Fold 0: 0.6315 ± 0.0151
#   Fold 1: 0.6142 ± 0.0135
#   Fold 2: 0.6605 ± 0.0175
#   Fold 3: 0.6667 ± 0.0152
#   Fold 4: 0.6440 ± 0.0107
#
# 7. MODEL SELECTION RECOMMENDATION:
# --------------------------------------------------
# ✅ RECOMMENDATION: Choose stable model
#    Score: 0.6679 (vs best: 0.6679)
#    Stability: 0.0146 (vs best: 0.0146)
#    Performance difference: 0.0000 (insignificant)
#
# 🎯 RECOMMENDED HYPERPARAMETERS:
#    clf__max_depth: 4
#    clf__max_features: 0.9539969835279999
#    clf__min_samples_leaf: 2
#    clf__min_samples_split: 10
#    clf__min_weight_fraction_leaf: 0.05718481349909639
#    clf__n_estimators: 435
#
# 8. GENERATING VISUALIZATIONS...
#
# 9. PRACTICAL INTERPRETATION FOR TRADING:
# --------------------------------------------------
# Expected Strategy Performance:
#   • Best mean_test_score: 0.6679
#   • Cross-validation Consistency: Good
#
# ✅ LOW RISK: Excellent consistency across CV folds
#    Strategy likely to perform similarly in live trading
#
# ================================================================================
# ANALYSIS COMPLETE
# ================================================================================
# SPECIFIC INSIGHTS FROM YOUR RESULTS:
# ================================================================================
#
# 1. KEY OBSERVATIONS:
# --------------------------------------------------
# max_depth: 4
# min_samples_leaf: 2
# min_samples_split: 10
# n_estimators: 435
# Best Model mean_test_score: 0.6679
# Standard Deviation: 0.0146
# Training Time: 1030.07s
#
# Best Simple Model (param_clf__max_depth ≤ 4):
#   param_clf__max_depth=4
#   mean_test_score: 0.6679 (vs best: 0.6679)
#
# 2. PERFORMANCE SATURATION:
# --------------------------------------------------
# Maximum performance by max_depth:
#   depth=3: 0.6453
#   depth=4: 0.6679
#   depth=5: 0.6508
#   depth=6: 0.6610
#
# 3. ACTIONABLE RECOMMENDATIONS:
# --------------------------------------------------
# ✅ Good baseline performance achieved
#    Ready for forward testing with proper risk management
#
# 4. PRODUCTION CONSIDERATIONS:
# --------------------------------------------------
# Expected Inference Speed: ~253.5ms per prediction
# Training Time Range: 29.63s to 1030.07s
# Average Model Size: ~303 trees
# ✅ Markdown report generated: Models\Bollinger_w10_std1_5\EURUSD\FUNDEDNEXT_STLR2_6K\tick\M1\20220101_20231231\18f7d38e\reports\hyperparameter_analysis_report.md
# 2025-12-16 13:05:27 | afml.production.model_development | INFO | Generated hyperparameter report: Models\Bollinger_w10_std1_5\EURUSD\FUNDEDNEXT_STLR2_6K\tick\M1\20220101_20231231\18f7d38e\reports\hyperparameter_analysis_report.md
# 2025-12-16 13:05:28 | afml.production.model_development | INFO | Generated feature importance plot: Models\Bollinger_w10_std1_5\EURUSD\FUNDEDNEXT_STLR2_6K\tick\M1\20220101_20231231\18f7d38e\plots\feature_importance.png
# 2025-12-16 13:05:28 | afml.production.model_development | WARNING | HTML summary generation failed: 'numpy.ndarray' object is not callable
# ✓ Reports generated in 3.83s
#
# [Saving] Writing artifacts to disk...
# 2025-12-16 13:05:32 | afml.production.model_development | INFO | Saved all artifacts to Models\Bollinger_w10_std1_5\EURUSD\FUNDEDNEXT_STLR2_6K\tick\M1\20220101_20231231\18f7d38e
# ✓ Saved to Models\Bollinger_w10_std1_5\EURUSD\FUNDEDNEXT_STLR2_6K\tick\M1\20220101_20231231\18f7d38e
# 2025-12-16 13:05:32 [info     ] pipeline_step                  duration_seconds=6423.236204624176 metrics={'total_duration': 6423.236204624176, 'model_trained': True, 'reports_generated': True} status=completed step=pipeline_complete
#
# ✓ Pipeline completed in 01:47:03
# ======================================================================

# %% [markdown]
# #### Optimize Trading Model with `Optuna`

# %%
from afml.cross_validation.hyper_fit_analysis import display_hyperparameter_report

# from afml.features.meta_labeling_features import add_meta_label_features
from afml.production.model_development import find_optimal_sample_weight

df0 = df[:"2022-03-31"]
events = generate_events_triple_barrier(df0, strategy, **label_config)
features = create_bollinger_features(df0)
best_weight, weight_cv_results, best_scheme = find_optimal_sample_weight(
    df0.index, events, features
)
print(best_scheme)

X = features.reindex(events.index)
y = events["bin"]
cv_results = weight_cv_results["cv_results"]
# Out:
# 2025-12-13 05:04:54 | afml.filters.filters | INFO | 1,971 CUSUM-filtered events
# 2025-12-13 05:04:54 | afml.strategies.signal_processing | INFO |
# Bollinger_w20_std1.5 | 1,137 (21.14%) trade events selected by CUSUM filter (threshold = 0.0820%).
#    Long signals:  577 (50.75%)
#    Short signals: 560 (49.25%)
#
# 2025-12-13 05:04:55 | afml.cache.unified_cache_system | DEBUG | Cache MISS: afml.production.model_development.generate_events_triple_barrier (key: 0949473e...) (1.20s)
# 2025-12-13 05:05:39 | afml.production.model_development | INFO | Best Weighting Scheme: Uniqueness Exp 0.00077
# 2025-12-13 05:05:39 | afml.cache.unified_cache_system | DEBUG | Cache MISS: afml.production.model_development.find_optimal_sample_weight (key: caa2bab3...) (42.78s)
# uniqueness_exp_0.0007787658410143283

# %%
from afml.cross_validation.optimized_hyper_fit import (
    analyze_pruning_effectiveness,
    optimize_trading_model_with_advanced_pruning,
    plot_pruning_analysis,
)


def main():
    """Example usage of the pruning optimization"""

    # Run optimization with pruning
    print("🚀 Starting optimization with pruning...")

    study = optimize_trading_model_with_advanced_pruning(
        X=X.reindex(events.index),
        y=events.bin,
        sample_weight=best_weight,
        events=events,
        n_trials=50,
        timeout=7200,  # 2 hours max
        n_splits=5,
        pruner_type="median",  # Try 'hyperband' for larger searches
    )

    # Print results
    print("\n" + "=" * 60)
    print("OPTIMIZATION COMPLETE")
    print("=" * 60)

    print("\n🏆 Best trial:")
    print(f"   Trial #{study.best_trial.number}")
    print(f"   Score (F1): {study.best_trial.value:.4f}")
    print("   Parameters:")
    for key, value in study.best_trial.params.items():
        print(f"     {key}: {value}")

    # Analyze pruning effectiveness
    pruning_stats = analyze_pruning_effectiveness(study)

    # Visualize results
    plot_pruning_analysis(study, save_path="pruning_analysis.png")

    # Save best model
    best_model = RandomForestClassifier(
        **study.best_trial.params, n_jobs=-1, random_state=42
    )

    # Train on full data
    best_model.fit(X.reindex(events.index), events.bin, sample_weight=best_weight)

    return study, best_model, pruning_stats

# %%
# res = []
# for n in range(10, 40, 10):
#     t0 = time.time()
#     best_weight, weight_cv_results = fin(df0.index, events, features, 3, n)
#     res.append(weight_cv_results)
#     print(f"\nComputation time (n_iter={n}): {timedelta(seconds=time.time() - t0)}")
#     print(weight_cv_results["best_params"])
# meta_features = add_meta_label_features(features, events, df0, best_weight)    print(weight_cv_results["best_params"])
# meta_features = add_meta_label_features(features, events, df0, best_weight)

# %%
best_scheme = "uniqueness_exp_0.33370978909090"
d = 0.33370978909090
f"{' '.join(best_scheme.split('_')).title()}"[: 7 - len(str(d))]
# Out:
# Reloading 'afml.production.model_development'.
# 'Uniqueness Exp 0.333709'

# %%
from afml.cross_validation.hyper_fit_analysis import (
    analyze_hyperparameter_results,
    analyze_your_results,
    generate_complete_hyperparameter_report,
)

# cv_results
analyze_your_results(weight_cv_results["cv_results"])
# Out:
# SPECIFIC INSIGHTS FROM YOUR RESULTS:
# ================================================================================
#
# 1. KEY OBSERVATIONS:
# --------------------------------------------------
# Best Model: max_depth=N/A, n_estimators=N/A
# F1 Score: 0.7395 ± 0.0392
# Training Time: 1.32s
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'param_clf__max_depth'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[50], line 5
#       1 from afml.cross_validation.hyper_fit_analysis import analyze_hyperparameter_results, analyze_your_results, generate_complete_hyperparameter_report
#       4 # cv_results
# ----> 5 analyze_your_results(weight_cv_results["cv_results"])
#
# File c:\users\joen\documents\github\machine-learning-blueprint\afml\cross_validation\hyper_fit_analysis.py:388, in analyze_your_results(cv_results)
#     385 print(f"Training Time: {best_model['mean_fit_time']:.2f}s")
#     387 # Compare with simpler models
# --> 388 simple_models = cv_results[cv_results["param_clf__max_depth"] <= 4]
#     389 if not simple_models.empty:
#     390     best_simple = simple_models.nlargest(1, "mean_test_score")
#
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'param_clf__max_depth'

# %%
bar_comparison_metrics = {}
for key, val in trained_models.items():
    try:
        inner_key = list(val.keys())[0]
        bar_comparison_metrics.setdefault(inner_key, {})
        if "time" in key:
            bar_comparison_metrics[inner_key]["time"] = val[inner_key]
        elif "tick" in key:
            bar_comparison_metrics[inner_key]["tick"] = val[inner_key]
    except:  # noqa: E722
        continue

len(bar_comparison_metrics.values())
# [keyify(training_cfg)]
# training_cfg
# Out:
# Reloading 'afml.production.model_development'.
# 1

# %%
from os import cpu_count

df_train = load_and_prepare_training_data(
    symbol,
    start_date,
    end_date,
    account_name,
    bar_type=data_config["bar_type"],
    bar_size=data_config["bar_size"],
    price=data_config["price"],
)
events_train = generate_events_triple_barrier(df_train, strategy, **label_config)
seq_rf = SequentiallyBootstrappedBaggingClassifier(
    samples_info_sets=events_train.t1,
    price_bars_index=df_train.index,
    random_state=42,
    n_estimators=10,
    n_jobs=cpu_count() - 1,
)
seq_params = model_params.copy()
seq_params["pipe_clf"] = seq_rf
seq_params["param_grid"] = {"n_estimators": randint(10, 101)}
seq_params["cv_splits"] = 3
seq_model, seq_model_features, seq_metrics, config = develop_production_model(
    symbol,
    start_date,
    end_date,
    strategy,
    data_config,
    feature_config,
    label_config,
    seq_params,
)
# Out:
# 2025-12-11 06:40:38:4038 | DEBUG    | afml.cache.unified_cache_system:track_cache_call:545 - Cache HIT: afml.production.model_development.load_and_prepare_training_data (key: add2b5af...)
# 2025-12-11 06:40:38:4038 | DEBUG    | afml.cache.unified_cache_system:track_cache_call:545 - Cache HIT: afml.production.model_development.generate_events_triple_barrier (key: 70a2ec1b...)
#
# ======================================================================
# PRODUCTION MODEL DEVELOPMENT PIPELINE
# ======================================================================
#
# Configuration
# --------------------------------------------------
# strategy                 Bollinger_w10_std1.5
# symbol                                 EURUSD
# account_name              FUNDEDNEXT_STLR2_6K
# bar_type                                 tick
# bar_size                                   M1
# price                               mid_price
# target_lookback                            20
# profit_target                               1
# stop_loss                                   2
# max_holding_period                {'days': 1}
# min_ret                                     0
# vertical_barrier_zero                    True
# filter_as_series                        False
#
# [Step 1/7] Loading training data...
# 2025-12-11 06:40:38:4038 | DEBUG    | afml.cache.unified_cache_system:track_cache_call:545 - Cache HIT: afml.production.model_development.load_and_prepare_training_data (key: add2b5af...)
# ✓ Loaded 1,009,134 samples from 2022-01-01 to 2023-12-31
#
# [Step 2/7] Computing features...
# 2025-12-11 06:40:40:4040 | DEBUG    | afml.cache.unified_cache_system:track_cache_call:545 - Cache HIT: afml.production.model_development.create_feature_engineering_pipeline (key: 771c1bb6...)
# ✓ Generated 70 features
#
# [Step 3/7] Generating events...
# 2025-12-11 06:40:40:4040 | DEBUG    | afml.cache.unified_cache_system:track_cache_call:545 - Cache HIT: afml.production.model_development.generate_events_triple_barrier (key: 70a2ec1b...)
# ✓ Generated events:
#       count  proportion
# bin
# 1    57,005    0.652492
# 0    30,360    0.347508
#
# Average Uniqueness: 0.4392
#
# [Step 4/7] Computing sample weights...
# 2025-12-11 06:40:41:4041 | DEBUG    | afml.cache.unified_cache_system:track_cache_call:545 - Cache HIT: afml.production.model_development.get_best_weighting_scheme (key: bb4a1e50...)
# 2025-12-11 06:40:41:4041 | DEBUG    | afml.production.model_development:get_best_sample_weight:753 - Computing unweighted weighting scheme
# 2025-12-11 06:40:41:4041 | DEBUG    | afml.cache.unified_cache_system:track_cache_call:545 - Cache HIT: afml.production.model_development.get_best_weighting_scheme (key: 703a6420...)
# 2025-12-11 06:40:41:4041 | DEBUG    | afml.production.model_development:get_best_sample_weight:753 - Computing uniqueness weighting scheme
# 2025-12-11 06:40:41:4041 | DEBUG    | afml.cache.unified_cache_system:track_cache_call:545 - Cache HIT: afml.production.model_development.get_best_weighting_scheme (key: 94452ea8...)
# 2025-12-11 06:40:41:4041 | DEBUG    | afml.production.model_development:get_best_sample_weight:753 - Computing return weighting scheme
# 2025-12-11 06:40:41:4041 | DEBUG    | afml.production.model_development:get_best_sample_weight:764 - uniqueness_exponential_decay_0.9
# 2025-12-11 06:40:42:4042 | DEBUG    | afml.cache.unified_cache_system:track_cache_call:545 - Cache HIT: afml.production.model_development.get_best_weighting_scheme (key: de745453...)
# 2025-12-11 06:40:42:4042 | DEBUG    | afml.production.model_development:get_best_sample_weight:777 - 0/6. Computing uniqueness_exponential_decay_0.9 weighting scheme
# 2025-12-11 06:40:42:4042 | DEBUG    | afml.production.model_development:get_best_sample_weight:764 - uniqueness_linear_decay_0.9
# 2025-12-11 06:40:42:4042 | DEBUG    | afml.cache.unified_cache_system:track_cache_call:545 - Cache HIT: afml.production.model_development.get_best_weighting_scheme (key: f5454e56...)
# 2025-12-11 06:40:42:4042 | DEBUG    | afml.production.model_development:get_best_sample_weight:777 - 0/6. Computing uniqueness_linear_decay_0.9 weighting scheme
# 2025-12-11 06:40:42:4042 | DEBUG    | afml.production.model_development:get_best_sample_weight:764 - uniqueness_exponential_decay_0.75
# 2025-12-11 06:40:42:4042 | DEBUG    | afml.cache.unified_cache_system:track_cache_call:545 - Cache HIT: afml.production.model_development.get_best_weighting_scheme (key: 6744596b...)
# 2025-12-11 06:40:42:4042 | DEBUG    | afml.production.model_development:get_best_sample_weight:777 - 0/6. Computing uniqueness_exponential_decay_0.75 weighting scheme
# 2025-12-11 06:40:42:4042 | DEBUG    | afml.production.model_development:get_best_sample_weight:764 - uniqueness_linear_decay_0.75
# 2025-12-11 06:40:42:4042 | DEBUG    | afml.cache.unified_cache_system:track_cache_call:545 - Cache HIT: afml.production.model_development.get_best_weighting_scheme (key: 5677943d...)
# 2025-12-11 06:40:42:4042 | DEBUG    | afml.production.model_development:get_best_sample_weight:777 - 0/6. Computing uniqueness_linear_decay_0.75 weighting scheme
# 2025-12-11 06:40:42:4042 | DEBUG    | afml.production.model_development:get_best_sample_weight:764 - uniqueness_exponential_decay_0.5
# 2025-12-11 06:40:42:4042 | DEBUG    | afml.cache.unified_cache_system:track_cache_call:545 - Cache HIT: afml.production.model_development.get_best_weighting_scheme (key: 380549b3...)
# 2025-12-11 06:40:42:4042 | DEBUG    | afml.production.model_development:get_best_sample_weight:777 - 0/6. Computing uniqueness_exponential_decay_0.5 weighting scheme
# 2025-12-11 06:40:42:4042 | DEBUG    | afml.production.model_development:get_best_sample_weight:764 - uniqueness_linear_decay_0.5
# 2025-12-11 06:42:26:4226 | DEBUG    | afml.cache.unified_cache_system:track_cache_call:545 - Cache MISS: afml.production.model_development.get_best_weighting_scheme (key: 7ba37e96...) (01:44)
# 2025-12-11 06:42:26:4226 | DEBUG    | afml.production.model_development:get_best_sample_weight:777 - 0/6. Computing uniqueness_linear_decay_0.5 weighting scheme
# 2025-12-11 06:42:26:4226 | DEBUG    | afml.production.model_development:get_best_sample_weight:764 - uniqueness_exponential_decay_0.25
# 2025-12-11 06:42:26:4226 | DEBUG    | afml.cache.unified_cache_system:track_cache_call:545 - Cache HIT: afml.production.model_development.get_best_weighting_scheme (key: d7303b19...)
# 2025-12-11 06:42:26:4226 | DEBUG    | afml.production.model_development:get_best_sample_weight:777 - 0/6. Computing uniqueness_exponential_decay_0.25 weighting scheme
# 2025-12-11 06:42:26:4226 | DEBUG    | afml.production.model_development:get_best_sample_weight:764 - uniqueness_linear_decay_0.25
# 2025-12-11 06:42:27:4227 | DEBUG    | afml.cache.unified_cache_system:track_cache_call:545 - Cache HIT: afml.production.model_development.get_best_weighting_scheme (key: 0b0c6e37...)
# 2025-12-11 06:42:27:4227 | DEBUG    | afml.production.model_development:get_best_sample_weight:777 - 0/6. Computing uniqueness_linear_decay_0.25 weighting scheme
# 2025-12-11 06:42:27:4227 | DEBUG    | afml.production.model_development:get_best_sample_weight:764 - uniqueness_exponential_decay_0.1
# 2025-12-11 06:42:27:4227 | DEBUG    | afml.cache.unified_cache_system:track_cache_call:545 - Cache HIT: afml.production.model_development.get_best_weighting_scheme (key: 1e158091...)
# 2025-12-11 06:42:27:4227 | DEBUG    | afml.production.model_development:get_best_sample_weight:777 - 0/6. Computing uniqueness_exponential_decay_0.1 weighting scheme
# 2025-12-11 06:42:27:4227 | DEBUG    | afml.production.model_development:get_best_sample_weight:764 - uniqueness_linear_decay_0.1
# 2025-12-11 06:42:28:4228 | DEBUG    | afml.cache.unified_cache_system:track_cache_call:545 - Cache HIT: afml.production.model_development.get_best_weighting_scheme (key: 04dd9e86...)
# 2025-12-11 06:42:28:4228 | DEBUG    | afml.production.model_development:get_best_sample_weight:777 - 0/6. Computing uniqueness_linear_decay_0.1 weighting scheme
# 2025-12-11 06:42:28:4228 | DEBUG    | afml.production.model_development:get_best_sample_weight:764 - uniqueness_exponential_decay_0.001
# 2025-12-11 06:42:29:4229 | DEBUG    | afml.cache.unified_cache_system:track_cache_call:545 - Cache HIT: afml.production.model_development.get_best_weighting_scheme (key: 188c60ee...)
# 2025-12-11 06:42:29:4229 | DEBUG    | afml.production.model_development:get_best_sample_weight:777 - 0/6. Computing uniqueness_exponential_decay_0.001 weighting scheme
# 2025-12-11 06:42:29:4229 | DEBUG    | afml.production.model_development:get_best_sample_weight:764 - uniqueness_linear_decay_0.001
# 2025-12-11 06:42:29:4229 | DEBUG    | afml.cache.unified_cache_system:track_cache_call:545 - Cache HIT: afml.production.model_development.get_best_weighting_scheme (key: ffedc334...)
# 2025-12-11 06:42:29:4229 | DEBUG    | afml.production.model_development:get_best_sample_weight:777 - 0/6. Computing uniqueness_linear_decay_0.001 weighting scheme
# 2025-12-11 06:42:29:4229 | INFO     | afml.production.model_development:get_best_sample_weight:779 -
# Best Weighting Scheme: Uniqueness Exponential Decay 0.001
#
# [Step 5/7] Computing rolling meta-label features...
# 2025-12-11 06:42:35:4235 | DEBUG    | afml.cache.unified_cache_system:track_cache_call:545 - Cache MISS: afml.production.model_development.calculate_rolling_metrics (key: 000251d6...) (5.33s)
# ✓ Computed rolling meta-label features
#
# [Step 6/7] Training model with cross-validation...
# ---------------------------------------------------------------------------
# PicklingError                             Traceback (most recent call last)
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\site-packages\joblib\hashing.py:110, in Hasher.save_global(self, obj, name, pack)
#     109 try:
# --> 110     Pickler.save_global(self, obj, **kwargs)
#     111 except pickle.PicklingError:
#
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\pickle.py:1076, in _Pickler.save_global(self, obj, name)
#    1075     if obj2 is not obj:
# -> 1076         raise PicklingError(
#    1077             "Can't pickle %r: it's not the same object as %s.%s" %
#    1078             (obj, module_name, name))
#    1080 if self.proto >= 2:
#
# PicklingError: Can't pickle <class 'afml.ensemble.sb_bagging.SequentiallyBootstrappedBaggingClassifier'>: it's not the same object as afml.ensemble.sb_bagging.SequentiallyBootstrappedBaggingClassifier
#
# During handling of the above exception, another exception occurred:
#
# PicklingError                             Traceback (most recent call last)
# Cell In[76], line 22
#      20 seq_params['param_grid'] = {'n_estimators': randint(10, 101)}
#      21 seq_params['cv_splits'] = 3
# ---> 22 seq_model, seq_model_features, seq_metrics, config = develop_production_model(
#      23                     symbol, start_date, end_date, strategy, data_cfg, feat_params, label_cfg, seq_params,
#      24                 )
#
# File c:\users\joen\documents\github\machine-learning-blueprint\afml\production\model_development.py:1157, in develop_production_model(symbol, train_start, train_end, strategy, data_config, feature_config, label_config, model_params, cache_reports, save)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File c:\users\joen\documents\github\machine-learning-blueprint\afml\production\model_development.py:961, in train_model_with_cv(features, events, sample_weight, pipe_clf, param_grid, cv_splits, bagging_n_estimators, bagging_max_samples, bagging_max_features, rnd_search_iter, n_jobs, pct_embargo, random_state, verbose)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File c:\users\joen\documents\github\machine-learning-blueprint\afml\cross_validation\hyper_fit.py:290, in clf_hyper_fit_cached(features, labels, t1, pipe_clf, param_grid, cv, bagging_n_estimators, bagging_max_samples, bagging_max_features, rnd_search_iter, n_jobs, pct_embargo, random_state, verbose, **fit_params)
#     287 param_grid_cacheable = create_cacheable_param_grid(param_grid)
#     289 # Call cached version
# --> 290 return clf_hyper_fit_internal(
#     291     features=features,
#     292     labels=labels,
#     293     t1=t1,
#     294     pipe_clf=pipe_clf,
#     295     param_grid_cacheable=param_grid_cacheable,
#     296     cv=cv,
#     297     bagging_n_estimators=bagging_n_estimators,
#     298     bagging_max_samples=bagging_max_samples,
#     299     bagging_max_features=bagging_max_features,
#     300     rnd_search_iter=rnd_search_iter,
#     301     n_jobs=n_jobs,
#     302     pct_embargo=pct_embargo,
#     303     random_state=random_state,
#     304     verbose=verbose,
#     305     **fit_params,
#     306 )
#
# File c:\users\joen\documents\github\machine-learning-blueprint\afml\cache\unified_cache_system.py:644, in cacheable.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     639 # Generate our custom cache key for tracking/monitoring
#     640 cache_key = UnifiedCacheKeyGenerator.generate_key(
#     641     func, args, kwargs, time_aware=time_aware, auto_versioning=auto_versioning
#     642 )
# --> 644 is_hit = cached_func.check_call_in_cache(*args, **kwargs)
#     645 computation_time = None
#     647 # Track for session
#
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\site-packages\joblib\memory.py:641, in MemorizedFunc.check_call_in_cache(self, *args, **kwargs)
#     625 def check_call_in_cache(self, *args, **kwargs):
#     626     """Check if the function call is cached and valid for given arguments.
#     627
#     628     Does not call the function or do any work besides function inspection
#    (...)
#     639         Whether or not the function call is in cache and can be used.
#     640     """
# --> 641     call_id = (self.func_id, self._get_args_id(*args, **kwargs))
#     642     return self._is_in_cache_and_valid(call_id)
#
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\site-packages\joblib\memory.py:650, in MemorizedFunc._get_args_id(self, *args, **kwargs)
#     648 def _get_args_id(self, *args, **kwargs):
#     649     """Return the input parameter hash of a result."""
# --> 650     return hashing.hash(
#     651         filter_args(self.func, self.ignore, args, kwargs),
#     652         coerce_mmap=self.mmap_mode is not None,
#     653     )
#
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\site-packages\joblib\hashing.py:270, in hash(obj, hash_name, coerce_mmap)
#     268 else:
#     269     hasher = Hasher(hash_name=hash_name)
# --> 270 return hasher.hash(obj)
#
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\site-packages\joblib\hashing.py:64, in Hasher.hash(self, obj, return_digest)
#      62 def hash(self, obj, return_digest=True):
#      63     try:
# ---> 64         self.dump(obj)
#      65     except pickle.PicklingError as e:
#      66         e.args += ("PicklingError while hashing %r: %r" % (obj, e),)
#
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\pickle.py:487, in _Pickler.dump(self, obj)
#     485 if self.proto >= 4:
#     486     self.framer.start_framing()
# --> 487 self.save(obj)
#     488 self.write(STOP)
#     489 self.framer.end_framing()
#
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\site-packages\joblib\hashing.py:244, in NumpyHasher.save(self, obj)
#     242     self._hash.update(pickle.dumps(obj))
#     243     return
# --> 244 Hasher.save(self, obj)
#
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\site-packages\joblib\hashing.py:90, in Hasher.save(self, obj)
#      88         cls = obj.__self__.__class__
#      89         obj = _MyHash(func_name, inst, cls)
# ---> 90 Pickler.save(self, obj)
#
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\pickle.py:560, in _Pickler.save(self, obj, save_persistent_id)
#     558 f = self.dispatch.get(t)
#     559 if f is not None:
# --> 560     f(self, obj)  # Call unbound method with explicit self
#     561     return
#     563 # Check private dispatch table if any, or else
#     564 # copyreg.dispatch_table
#
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\pickle.py:972, in _Pickler.save_dict(self, obj)
#     969     self.write(MARK + DICT)
#     971 self.memoize(obj)
# --> 972 self._batch_setitems(obj.items())
#
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\site-packages\joblib\hashing.py:143, in Hasher._batch_setitems(self, items, *args)
#     136 def _batch_setitems(self, items, *args):
#     137     # forces order of keys in dict to ensure consistent hash.
#     138     try:
#     139         # Trying first to compare dict assuming the type of keys is
#     140         # consistent and orderable.
#     141         # This fails on python 3 when keys are unorderable
#     142         # but we keep it in a try as it's faster.
# --> 143         Pickler._batch_setitems(self, iter(sorted(items)), *args)
#     144     except TypeError:
#     145         # If keys are unorderable, sorting them using their hash. This is
#     146         # slower but works in any case.
#     147         Pickler._batch_setitems(
#     148             self, iter(sorted((hash(k), v) for k, v in items)), *args
#     149         )
#
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\pickle.py:998, in _Pickler._batch_setitems(self, items)
#     996     for k, v in tmp:
#     997         save(k)
# --> 998         save(v)
#     999     write(SETITEMS)
#    1000 elif n:
#
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\site-packages\joblib\hashing.py:244, in NumpyHasher.save(self, obj)
#     242     self._hash.update(pickle.dumps(obj))
#     243     return
# --> 244 Hasher.save(self, obj)
#
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\site-packages\joblib\hashing.py:90, in Hasher.save(self, obj)
#      88         cls = obj.__self__.__class__
#      89         obj = _MyHash(func_name, inst, cls)
# ---> 90 Pickler.save(self, obj)
#
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\pickle.py:603, in _Pickler.save(self, obj, save_persistent_id)
#     599     raise PicklingError("Tuple returned by %s must have "
#     600                         "two to six elements" % reduce)
#     602 # Save the reduce() output and finally memoize the object
# --> 603 self.save_reduce(obj=obj, *rv)
#
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\pickle.py:717, in _Pickler.save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     715 if state is not None:
#     716     if state_setter is None:
# --> 717         save(state)
#     718         write(BUILD)
#     719     else:
#     720         # If a state_setter is specified, call it instead of load_build
#     721         # to update obj's with its previous state.
#     722         # First, push state_setter and its tuple of expected arguments
#     723         # (obj, state) onto the stack.
#
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\site-packages\joblib\hashing.py:244, in NumpyHasher.save(self, obj)
#     242     self._hash.update(pickle.dumps(obj))
#     243     return
# --> 244 Hasher.save(self, obj)
#
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\site-packages\joblib\hashing.py:90, in Hasher.save(self, obj)
#      88         cls = obj.__self__.__class__
#      89         obj = _MyHash(func_name, inst, cls)
# ---> 90 Pickler.save(self, obj)
#
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\pickle.py:560, in _Pickler.save(self, obj, save_persistent_id)
#     558 f = self.dispatch.get(t)
#     559 if f is not None:
# --> 560     f(self, obj)  # Call unbound method with explicit self
#     561     return
#     563 # Check private dispatch table if any, or else
#     564 # copyreg.dispatch_table
#
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\pickle.py:972, in _Pickler.save_dict(self, obj)
#     969     self.write(MARK + DICT)
#     971 self.memoize(obj)
# --> 972 self._batch_setitems(obj.items())
#
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\site-packages\joblib\hashing.py:143, in Hasher._batch_setitems(self, items, *args)
#     136 def _batch_setitems(self, items, *args):
#     137     # forces order of keys in dict to ensure consistent hash.
#     138     try:
#     139         # Trying first to compare dict assuming the type of keys is
#     140         # consistent and orderable.
#     141         # This fails on python 3 when keys are unorderable
#     142         # but we keep it in a try as it's faster.
# --> 143         Pickler._batch_setitems(self, iter(sorted(items)), *args)
#     144     except TypeError:
#     145         # If keys are unorderable, sorting them using their hash. This is
#     146         # slower but works in any case.
#     147         Pickler._batch_setitems(
#     148             self, iter(sorted((hash(k), v) for k, v in items)), *args
#     149         )
#
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\pickle.py:998, in _Pickler._batch_setitems(self, items)
#     996     for k, v in tmp:
#     997         save(k)
# --> 998         save(v)
#     999     write(SETITEMS)
#    1000 elif n:
#
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\site-packages\joblib\hashing.py:244, in NumpyHasher.save(self, obj)
#     242     self._hash.update(pickle.dumps(obj))
#     243     return
# --> 244 Hasher.save(self, obj)
#
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\site-packages\joblib\hashing.py:90, in Hasher.save(self, obj)
#      88         cls = obj.__self__.__class__
#      89         obj = _MyHash(func_name, inst, cls)
# ---> 90 Pickler.save(self, obj)
#
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\pickle.py:560, in _Pickler.save(self, obj, save_persistent_id)
#     558 f = self.dispatch.get(t)
#     559 if f is not None:
# --> 560     f(self, obj)  # Call unbound method with explicit self
#     561     return
#     563 # Check private dispatch table if any, or else
#     564 # copyreg.dispatch_table
#
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\pickle.py:932, in _Pickler.save_list(self, obj)
#     929     self.write(MARK + LIST)
#     931 self.memoize(obj)
# --> 932 self._batch_appends(obj)
#
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\pickle.py:959, in _Pickler._batch_appends(self, items)
#     957     write(APPENDS)
#     958 elif n:
# --> 959     save(tmp[0])
#     960     write(APPEND)
#     961 # else tmp is empty, and we're done
#
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\site-packages\joblib\hashing.py:244, in NumpyHasher.save(self, obj)
#     242     self._hash.update(pickle.dumps(obj))
#     243     return
# --> 244 Hasher.save(self, obj)
#
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\site-packages\joblib\hashing.py:90, in Hasher.save(self, obj)
#      88         cls = obj.__self__.__class__
#      89         obj = _MyHash(func_name, inst, cls)
# ---> 90 Pickler.save(self, obj)
#
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\pickle.py:560, in _Pickler.save(self, obj, save_persistent_id)
#     558 f = self.dispatch.get(t)
#     559 if f is not None:
# --> 560     f(self, obj)  # Call unbound method with explicit self
#     561     return
#     563 # Check private dispatch table if any, or else
#     564 # copyreg.dispatch_table
#
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\pickle.py:887, in _Pickler.save_tuple(self, obj)
#     885 if n <= 3 and self.proto >= 2:
#     886     for element in obj:
# --> 887         save(element)
#     888     # Subtle.  Same as in the big comment below.
#     889     if id(obj) in memo:
#
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\site-packages\joblib\hashing.py:244, in NumpyHasher.save(self, obj)
#     242     self._hash.update(pickle.dumps(obj))
#     243     return
# --> 244 Hasher.save(self, obj)
#
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\site-packages\joblib\hashing.py:90, in Hasher.save(self, obj)
#      88         cls = obj.__self__.__class__
#      89         obj = _MyHash(func_name, inst, cls)
# ---> 90 Pickler.save(self, obj)
#
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\pickle.py:603, in _Pickler.save(self, obj, save_persistent_id)
#     599     raise PicklingError("Tuple returned by %s must have "
#     600                         "two to six elements" % reduce)
#     602 # Save the reduce() output and finally memoize the object
# --> 603 self.save_reduce(obj=obj, *rv)
#
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\pickle.py:687, in _Pickler.save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     684     raise PicklingError(
#     685         "args[0] from __newobj__ args has the wrong class")
#     686 args = args[1:]
# --> 687 save(cls)
#     688 save(args)
#     689 write(NEWOBJ)
#
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\site-packages\joblib\hashing.py:244, in NumpyHasher.save(self, obj)
#     242     self._hash.update(pickle.dumps(obj))
#     243     return
# --> 244 Hasher.save(self, obj)
#
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\site-packages\joblib\hashing.py:90, in Hasher.save(self, obj)
#      88         cls = obj.__self__.__class__
#      89         obj = _MyHash(func_name, inst, cls)
# ---> 90 Pickler.save(self, obj)
#
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\pickle.py:572, in _Pickler.save(self, obj, save_persistent_id)
#     568 else:
#     569     # Check for a class with a custom metaclass; treat as regular
#     570     # class
#     571     if issubclass(t, type):
# --> 572         self.save_global(obj)
#     573         return
#     575     # Check for a __reduce_ex__ method, fall back to __reduce__
#
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\site-packages\joblib\hashing.py:112, in Hasher.save_global(self, obj, name, pack)
#     110     Pickler.save_global(self, obj, **kwargs)
#     111 except pickle.PicklingError:
# --> 112     Pickler.save_global(self, obj, **kwargs)
#     113     module = getattr(obj, "__module__", None)
#     114     if module == "__main__":
#
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\pickle.py:1076, in _Pickler.save_global(self, obj, name)
#    1074 else:
#    1075     if obj2 is not obj:
# -> 1076         raise PicklingError(
#    1077             "Can't pickle %r: it's not the same object as %s.%s" %
#    1078             (obj, module_name, name))
#    1080 if self.proto >= 2:
#    1081     code = _extension_registry.get((module_name, name))
#
# PicklingError: ("Can't pickle <class 'afml.ensemble.sb_bagging.SequentiallyBootstrappedBaggingClassifier'>: it's not the same object as afml.ensemble.sb_bagging.SequentiallyBootstrappedBaggingClassifier", 'PicklingError while hashing {\'features\':                               spread  parkinson_vol_10    h1_vol    h4_vol  \\\ntime                                                                         \n2022-03-28 00:08:55.917001  0.000086          0.000099  0.000222  0.000244   \n2022-03-28 01:04:16.651001  0.000092          0.000103  0.000091  0.000089   \n2022-03-28 01:19:13.204001  0.000089          0.000090  0.000191  0.000102   \n2022-03-28 01:52:00.561001  0.000074          0.000080  0.000122  0.000092   \n2022-03-28 02:16:52.895001  0.000083          0.000073  0.000140  0.000069   \n...                              ...               ...       ...       ...   \n2023-10-27 16:36:45.746001  0.000080          0.000116  0.000672  0.000313   \n2023-10-27 16:42:46.576001  0.000070          0.000113  0.000326  0.000424   \n2023-10-27 16:48:50.006001  0.000067          0.000129  0.000356  0.000397   \n2023-10-27 16:54:36.768001  0.000072          0.000119  0.000220  0.000228   \n2023-10-27 16:56:51.056001  0.000073          0.000106  0.000217  0.000384   \n\n                              d1_vol       ret     ret_5    ret_10  \\\ntime                                                                 \n2022-03-28 00:08:55.917001  0.000658  0.138617 -0.009040 -0.018683   \n2022-03-28 01:04:16.651001  0.000140 -0.929871 -0.230292 -0.017402   \n2022-03-28 01:19:13.204001  0.000117 -0.559594  0.376611 -0.142394   \n2022-03-28 01:52:00.561001  0.000094  0.228433 -0.114217  0.034340   \n2022-03-28 02:16:52.895001  0.000069  0.687792 -0.050066 -0.044321   \n...                              ...       ...       ...       ...   \n2023-10-27 16:36:45.746001  0.000277  2.812288  0.293867 -0.191116   \n2023-10-27 16:42:46.576001  0.000535  0.336606 -0.772183 -0.642515   \n2023-10-27 16:48:50.006001  0.000371  0.437376  0.263346 -0.139039   \n2023-10-27 16:54:36.768001  0.000293  0.955053  0.143308  0.048103   \n2023-10-27 16:56:51.056001  0.000383  0.087536  1.140207  0.534192   \n\n                            ret_1_lag_1  ret_5_lag_1  ...  london_session_vol  \\\ntime                                                  ...                       \n2022-03-28 00:08:55.917001    -1.841199    -0.027723  ...            0.000138   \n2022-03-28 01:04:16.651001     0.133419     0.194907  ...            0.000138   \n2022-03-28 01:19:13.204001     0.508359    -0.660734  ...            0.000138   \n2022-03-28 01:52:00.561001    -2.338083     0.182149  ...            0.000138   \n2022-03-28 02:16:52.895001    -0.875745    -0.037755  ...            0.000138   \n...                                 ...          ...  ...                 ...   \n2023-10-27 16:36:45.746001    -0.528653    -0.676100  ...            0.000140   \n2023-10-27 16:42:46.576001    -1.512081    -0.512319  ...            0.000140   \n2023-10-27 16:48:50.006001     0.585623    -0.540965  ...            0.000140   \n2023-10-27 16:54:36.768001     0.436939    -0.047602  ...            0.000140   \n2023-10-27 16:56:51.056001     2.984066    -0.071263  ...            0.000140   \n\n                            ny_session_vol  session_overlap_vol  \\\ntime                                                              \n2022-03-28 00:08:55.917001        0.000086             0.000089   \n2022-03-28 01:04:16.651001        0.000086             0.000110   \n2022-03-28 01:19:13.204001        0.000086             0.000088   \n2022-03-28 01:52:00.561001        0.000086             0.000097   \n2022-03-28 02:16:52.895001        0.000086             0.000091   \n...                                    ...                  ...   \n2023-10-27 16:36:45.746001        0.000129             0.000140   \n2023-10-27 16:42:46.576001        0.000136             0.000140   \n2023-10-27 16:48:50.006001        0.000125    ...

# %% [markdown]
# #### Hyper-Parameter Tuning Analysis

# %%
# Run comprehensive analysis
from afml.cross_validation.hyper_fit_analysis import (
    analyze_hyperparameter_results,
    analyze_your_results,
)

print(pd.Series(config).to_string(), "\n")

cv_results = metrics["cv_results"]["cv_results"]
analysis = analyze_hyperparameter_results(
    cv_results=cv_results,  # Your DataFrame
    target_metric="mean_test_score",
    # time_constraint=10.0,  # Optional: maximum training time
    stability_threshold=0.03,
)
# Out:
# strategy                 Bollinger_w5_std1.5
# symbol                                EURUSD
# account_name             FUNDEDNEXT_STLR2_6K
# train_start                       2022-01-01
# train_end                         2023-12-31
# bar_type                                time
# bar_size                                  M1
# price                              mid_price
# target_lookback                           20
# profit_target                              1
# stop_loss                                  2
# max_holding_period               {'days': 1}
# min_ret                                    0
# vertical_barrier_zero                   True
# filter_as_series                       False
#
# ================================================================================
# HYPERPARAMETER ANALYSIS REPORT
# ================================================================================
#
# 1. TOP PERFORMING MODELS (sorted by mean_test_score):
# --------------------------------------------------
#                                                                                                                                                                                                                                                params  mean_test_score  std_test_score  mean_fit_time
# 4    {'clf__max_depth': 5, 'clf__max_features': 0.9599404067363205, 'clf__max_samples': 0.7803075385877797, 'clf__min_samples_leaf': 9, 'clf__min_samples_split': 8, 'clf__min_weight_fraction_leaf': 0.016632480579933266, 'clf__n_estimators': 138}         0.665123        0.040637     363.035444
# 1   {'clf__max_depth': 13, 'clf__max_features': 0.5592488919658671, 'clf__max_samples': 0.4337086111390218, 'clf__min_samples_leaf': 8, 'clf__min_samples_split': 4, 'clf__min_weight_fraction_leaf': 0.020292247147901225, 'clf__n_estimators': 307}         0.662289        0.034896     382.687531
# 3   {'clf__max_depth': 14, 'clf__max_features': 0.12306242504141576, 'clf__max_samples': 0.6247746602583891, 'clf__min_samples_leaf': 3, 'clf__min_samples_split': 13, 'clf__min_weight_fraction_leaf': 0.2671172192068058, 'clf__n_estimators': 369}         0.655306        0.031565      33.209913
# 28   {'clf__max_depth': 12, 'clf__max_features': 0.3579416277151556, 'clf__max_samples': 0.759984046034179, 'clf__min_samples_leaf': 9, 'clf__min_samples_split': 18, 'clf__min_weight_fraction_leaf': 0.13092614545022585, 'clf__n_estimators': 353}         0.645919        0.034258     153.344519
# 25   {'clf__max_depth': 4, 'clf__max_features': 0.7335297107608947, 'clf__max_samples': 0.6357746840747585, 'clf__min_samples_leaf': 1, 'clf__min_samples_split': 10, 'clf__min_weight_fraction_leaf': 0.17039003248586793, 'clf__n_estimators': 375}         0.645638        0.034617     205.927957
# 13     {'clf__max_depth': 7, 'clf__max_features': 0.829606178338064, 'clf__max_samples': 0.7375574713552131, 'clf__min_samples_leaf': 3, 'clf__min_samples_split': 2, 'clf__min_weight_fraction_leaf': 0.20146343737689493, 'clf__n_estimators': 480}         0.645554        0.034142     341.041831
# 9    {'clf__max_depth': 10, 'clf__max_features': 0.9445338486781514, 'clf__max_samples': 0.8473201101373808, 'clf__min_samples_leaf': 5, 'clf__min_samples_split': 14, 'clf__min_weight_fraction_leaf': 0.08046211248738132, 'clf__n_estimators': 64}         0.645392        0.033835     103.156999
# 29  {'clf__max_depth': 14, 'clf__max_features': 0.6582934536070976, 'clf__max_samples': 0.9826363431893397, 'clf__min_samples_leaf': 7, 'clf__min_samples_split': 10, 'clf__min_weight_fraction_leaf': 0.14943567629609095, 'clf__n_estimators': 196}         0.645312        0.033184     131.097238
# 24  {'clf__max_depth': 6, 'clf__max_features': 0.18085332633271525, 'clf__max_samples': 0.46965445606140444, 'clf__min_samples_leaf': 1, 'clf__min_samples_split': 7, 'clf__min_weight_fraction_leaf': 0.19389156635962662, 'clf__n_estimators': 421}         0.644842        0.032313      54.925583
# 11     {'clf__max_depth': 13, 'clf__max_features': 0.29884240408880514, 'clf__max_samples': 0.81134195274865, 'clf__min_samples_leaf': 3, 'clf__min_samples_split': 2, 'clf__min_weight_fraction_leaf': 0.3129799873905057, 'clf__n_estimators': 280}         0.644453        0.031849      51.638471
#
# 2. PERFORMANCE SUMMARY:
# --------------------------------------------------
# Average mean_test_score: 0.6323 ± 0.0397
# Best mean_test_score: 0.6651
# Worst mean_test_score: 0.4832
# Performance Range: 0.1819
#
# 3. STABILITY ANALYSIS:
# --------------------------------------------------
# Models with stable performance (std ≤ 0.03): 1
# Best stable model: 0.6420 ± 0.0278
#
# 4. TIME-EFFICIENCY ANALYSIS:
# --------------------------------------------------
#
# 5. HYPERPARAMETER TRENDS:
# --------------------------------------------------
#
# Parameter: clf__max_depth
# Optimal value: 5 (score: 0.6651)
# Performance by value:
#                       score_mean  score_std  count  fold_std_mean  time_mean
# param_clf__max_depth
# 5                         0.6651        NaN      1         0.0406   363.0354
# 13                        0.6534     0.0126      2         0.0334   217.1630
# 12                        0.6459        NaN      1         0.0343    76.6891
# 4                         0.6450     0.0009      2         0.0341   126.2181
# 7                         0.6449     0.0010      2         0.0325   210.2585
# 6                         0.6448        NaN      1         0.0323    27.4809
# 10                        0.6437     0.0024      2         0.0308   109.4110
# 15                        0.6416        NaN      1         0.0333    16.8128
# 17                        0.6405        NaN      1         0.0337    10.6194
# 16                        0.6352     0.0118      2         0.0365   198.9265
# 18                        0.6289        NaN      1         0.0396    13.1526
# 19                        0.6138        NaN      1         0.0504     6.2199
# 9                         0.6114     0.0565      3         0.0467    72.6538
# 14                        0.5946     0.0966      3         0.0601    51.5156
# 11                           NaN        NaN      0            NaN     0.0346
#
# Parameter: clf__max_features
# Optimal value: 0.9599404067363205 (score: 0.6651)
# Performance by value:
#                          score_mean  score_std  count  fold_std_mean  time_mean
# param_clf__max_features
# 0.959940                     0.6651        NaN      1         0.0406   363.0354
# 0.559249                     0.6623        NaN      1         0.0349   382.6875
# 0.123062                     0.6553        NaN      1         0.0316    33.2099
# 0.357942                     0.6459        NaN      1         0.0343   153.3445
# 0.829606                     0.6456        NaN      1         0.0341   341.0418
# 0.733530                     0.6456        NaN      1         0.0346   205.9280
# 0.944534                     0.6454        NaN      1         0.0338   103.1570
# 0.658293                     0.6453        NaN      1         0.0332   131.0972
# 0.180853                     0.6448        NaN      1         0.0323    54.9256
# 0.298842                     0.6445        NaN      1         0.0318    51.6385
# 0.724354                     0.6444        NaN      1         0.0335    46.5083
# 0.445071                     0.6442        NaN      1         0.0310    79.4751
# 0.896543                     0.6441        NaN      1         0.0330   119.3363
# 0.709997                     0.6439        NaN      1         0.0305    63.7878
# 0.948914                     0.6436        NaN      1         0.0306   285.2283
# 0.855361                     0.6420        NaN      1         0.0278   115.6650
# 0.960731                     0.6416        NaN      1         0.0333    33.5827
# 0.527541                     0.6405        NaN      1         0.0337    10.6194
# 0.140775                     0.6289        NaN      1         0.0396    13.1526
# 0.908397                     0.6269        NaN      1         0.0423   112.6247
# 0.353915                     0.6138        NaN      1         0.0504    12.4052
# 0.274366                     0.5461        NaN      1         0.0767    34.8374
# 0.516510                     0.4832        NaN      1         0.1156    93.1893
# 0.174551                        NaN        NaN      0            NaN     0.0430
# 0.437615                        NaN        NaN      0            NaN     0.0336
# 1.007566                        NaN        NaN      0            NaN     0.0362
# 1.014960                        NaN        NaN      0            NaN     0.0346
# 1.038553                        NaN        NaN      0            NaN     0.0450
# 1.039499                        NaN        NaN      0            NaN     0.0364
# 1.097740                        NaN        NaN      0            NaN     0.0346
#
# Parameter: clf__max_samples
# Optimal value: 0.7803075385877797 (score: 0.6651)
# Performance by value:
#                         score_mean  score_std  count  fold_std_mean  time_mean
# param_clf__max_samples
# 0.780308                    0.6651        NaN      1         0.0406   363.0354
# 0.433709                    0.6623        NaN      1         0.0349   382.6875
# 0.624775                    0.6553        NaN      1         0.0316    33.2099
# 0.759984                    0.6459        NaN      1         0.0343   153.3445
# 0.635775                    0.6456        NaN      1         0.0346   205.9280
# 0.737557                    0.6456        NaN      1         0.0341   341.0418
# 0.847320                    0.6454        NaN      1         0.0338   103.1570
# 0.982636                    0.6453        NaN      1         0.0332   131.0972
# 0.469654                    0.6448        NaN      1         0.0323    54.9256
# 0.811342                    0.6445        NaN      1         0.0318    51.6385
# 0.395634                    0.6444        NaN      1         0.0335    46.5083
# 0.734351                    0.6442        NaN      1         0.0310    79.4751
# 0.283435                    0.6441        NaN      1         0.0330   119.3363
# 0.933195                    0.6439        NaN      1         0.0305    63.7878
# 0.821730                    0.6436        NaN      1         0.0306   285.2283
# 0.525156                    0.6420        NaN      1         0.0278   115.6650
# 0.106952                    0.6416        NaN      1         0.0333    33.5827
# 0.125419                    0.6405        NaN      1         0.0337    10.6194
# 0.690893                    0.6289        NaN      1         0.0396    13.1526
# 0.404614                    0.6269        NaN      1         0.0423   112.6247
# 0.346876                    0.6138        NaN      1         0.0504    12.4052
# 0.790938                    0.5461        NaN      1         0.0767    34.8374
# 0.983280                    0.4832        NaN      1         0.1156    93.1893
# 0.100779                       NaN        NaN      0            NaN     0.0450
# 0.349292                       NaN        NaN      0            NaN     0.0362
# 0.366781                       NaN        NaN      0            NaN     0.0346
# 0.950039                       NaN        NaN      0            NaN     0.0346
# 0.994827                       NaN        NaN      0            NaN     0.0364
# 1.042910                       NaN        NaN      0            NaN     0.0336
# 1.086887                       NaN        NaN      0            NaN     0.0430
#
# Parameter: clf__min_samples_leaf
# Optimal value: 9 (score: 0.6555)
# Performance by value:
#                              score_mean  score_std  count  fold_std_mean  time_mean
# param_clf__min_samples_leaf
# 9                                0.6555     0.0136      2         0.0374   258.1900
# 8                                0.6493     0.0113      3         0.0337   107.1372
# 3                                0.6460     0.0056      5         0.0324   100.0595
# 1                                0.6452     0.0006      2         0.0335   130.4268
# 2                                0.6442        NaN      1         0.0310    26.5148
# 6                                0.6420        NaN      1         0.0278    57.8493
# 5                                0.6389     0.0104      3         0.0366    65.5837
# 4                                0.6289        NaN      1         0.0396     6.5944
# 7                                0.5864     0.0703      5         0.0613   111.3515
#
# Parameter: clf__min_samples_split
# Optimal value: 13 (score: 0.6497)
# Performance by value:
#                               score_mean  score_std  count  fold_std_mean  time_mean
# param_clf__min_samples_split
# 13                                0.6497     0.0079      2         0.0313    56.3425
# 18                                0.6459        NaN      1         0.0343   153.3445
# 4                                 0.6456     0.0236      2         0.0372   197.9201
# 14                                0.6454        NaN      1         0.0338    51.5966
# 2                                 0.6450     0.0008      2         0.0330    78.5606
# 7                                 0.6446     0.0003      2         0.0329    50.7170
# 10                                0.6442     0.0023      3         0.0337    92.6604
# 15                                0.6438     0.0003      2         0.0306   116.3508
# 11                                0.6420        NaN      1         0.0278   115.6650
# 3                                 0.6204     0.0093      2         0.0464    41.6882
# 8                                 0.6082     0.0840      4         0.0557   146.5451
# 19                                0.5461        NaN      1         0.0767    34.8374
#
# 6. CROSS-VALIDATION CONSISTENCY:
# --------------------------------------------------
# Fold performance consistency:
#   Fold 0: 0.6194 ± 0.0384
#   Fold 1: 0.6000 ± 0.0437
#   Fold 2: 0.6224 ± 0.0498
#   Fold 3: 0.6122 ± 0.0668
#   Fold 4: 0.7076 ± 0.0058
#
# ⚠️  High variance folds detected (std > 0.03):
#   Fold 0: std = 0.0384
#   Fold 1: std = 0.0437
#   Fold 2: std = 0.0498
#   Fold 3: std = 0.0668
#
# 7. MODEL SELECTION RECOMMENDATION:
# --------------------------------------------------
# ✅ RECOMMENDATION: Choose best performing model
#    Score: 0.6651 (vs stable: 0.6420)
#    Stability: 0.0406 (slightly higher variance)
#    Performance gain: 0.0231 (worth the risk)
#
# 🎯 RECOMMENDED HYPERPARAMETERS:
#    clf__max_depth: 5
#    clf__max_features: 0.9599404067363205
#    clf__max_samples: 0.7803075385877797
#    clf__min_samples_leaf: 9
#    clf__min_samples_split: 8
#    clf__min_weight_fraction_leaf: 0.016632480579933266
#    clf__n_estimators: 138
#
# 8. GENERATING VISUALIZATIONS...
#
# 9. PRACTICAL INTERPRETATION FOR TRADING:
# --------------------------------------------------
# Expected Strategy Performance:
#   • Best mean_test_score: 0.6651
#   • Cross-validation Consistency: Moderate
#
# ⚠️  RISK WARNING: High variance in CV folds
#    Strategy may perform inconsistently in live trading
#
# ================================================================================
# ANALYSIS COMPLETE
# ================================================================================

# %%
# Run specific analysis for your results
specific_insights = analyze_your_results(cv_results)
# Out:
# SPECIFIC INSIGHTS FROM YOUR RESULTS:
# ================================================================================
#
# 1. KEY OBSERVATIONS:
# --------------------------------------------------
# max_depth: 13
# min_samples_leaf: 8
# min_samples_split: 4
# n_estimators: 307
# Best Model mean_test_score: 0.6753
# Standard Deviation: 0.0311
# Training Time: 182.20s
#
# Best Simple Model (param_clf__max_depth ≤ 4):
#   param_clf__max_depth=4
#   mean_test_score: 0.6451 (vs best: 0.6753)
#
# 2. PERFORMANCE SATURATION:
# --------------------------------------------------
# Maximum performance by max_depth:
#   depth=4: 0.6451
#   depth=5: 0.6471
#   depth=6: 0.6578
#   depth=7: 0.6455
#   depth=9: 0.6486
#   depth=10: 0.6438
#   depth=11: nan
#   depth=12: 0.6473
#   depth=13: 0.6753
#   depth=14: 0.6640
#   depth=15: 0.6505
#   depth=16: 0.6412
#   depth=17: 0.6464
#   depth=18: 0.6740
#   depth=19: 0.6487
#
# 3. ACTIONABLE RECOMMENDATIONS:
# --------------------------------------------------
# ✅ Good baseline performance achieved
#    Ready for forward testing with proper risk management
#
# 4. PRODUCTION CONSIDERATIONS:
# --------------------------------------------------
# Expected Inference Speed: ~122.2ms per prediction
# Training Time Range: 0.01s to 182.20s
# Average Model Size: ~275 trees

# %% [markdown]
# #### Test Set Analysis

# %%
from afml.production.utils import ModelFileManager

time_path = Path(r"Models\Bollinger_w10_std1_5\EURUSD\FUNDEDNEXT_STLR2_6K\time\M1\20220101_20231231\bdad004f")
tick_path = Path(r"Models\Bollinger_w10_std1_5\EURUSD\FUNDEDNEXT_STLR2_6K\tick\M1\20220101_20231231\18f7d38e")

file_manager = ModelFileManager()

for path, bars in zip([time_path, tick_path], ["time", "tick"]):
    files = file_manager.find_models(base_dir=path)
    print(f"{bars}:")
    for file in files:
        print(file)
# Out:
# time:
# {'file_path': 'Models\\Bollinger_w10_std1_5\\EURUSD\\FUNDEDNEXT_STLR2_6K\\time\\M1\\20220101_20231231\\bdad004f\\rf_Bollinger_w10_std1_5_EURUSD_time_M1_20220101_20231231_pr-1_st-2_ta-10_20251215_130317.pkl', 'file_name': 'rf_Bollinger_w10_std1_5_EURUSD_time_M1_20220101_20231231_pr-1_st-2_ta-10_20251215_130317.pkl', 'strategy': 'EURUSD', 'symbol': 'FUNDEDNEXT_STLR2_6K', 'account': 'time', 'bar_type': 'M1', 'bar_size': '20220101_20231231', 'date_range': 'bdad004f', 'config_hash': 'rf_Bollinger_w10_std1_5_EURUSD_time_M1_20220101_20231231_pr-1_st-2_ta-10_20251215_130317.pkl', 'model_type': 'rf', 'strategy_from_file': 'Bollinger', 'symbol_from_file': 'w10', 'bar_type_from_file': 'std1', 'bar_size_from_file': '5', 'date_range_from_file': 'EURUSD'}
# {'file_path': 'Models\\Bollinger_w10_std1_5\\EURUSD\\FUNDEDNEXT_STLR2_6K\\time\\M1\\20220101_20231231\\bdad004f\\rf_Bollinger_w10_std1_5_EURUSD_time_M1_20220101_20231231_pr-1_st-2_ta-10_20251215_220059.pkl', 'file_name': 'rf_Bollinger_w10_std1_5_EURUSD_time_M1_20220101_20231231_pr-1_st-2_ta-10_20251215_220059.pkl', 'strategy': 'EURUSD', 'symbol': 'FUNDEDNEXT_STLR2_6K', 'account': 'time', 'bar_type': 'M1', 'bar_size': '20220101_20231231', 'date_range': 'bdad004f', 'config_hash': 'rf_Bollinger_w10_std1_5_EURUSD_time_M1_20220101_20231231_pr-1_st-2_ta-10_20251215_220059.pkl', 'model_type': 'rf', 'strategy_from_file': 'Bollinger', 'symbol_from_file': 'w10', 'bar_type_from_file': 'std1', 'bar_size_from_file': '5', 'date_range_from_file': 'EURUSD'}
# {'file_path': 'Models\\Bollinger_w10_std1_5\\EURUSD\\FUNDEDNEXT_STLR2_6K\\time\\M1\\20220101_20231231\\bdad004f\\rf_Bollinger_w10_std1_5_EURUSD_time_M1_20220101_20231231_pr-1_st-2_ta-10_20251216_111408.pkl', 'file_name': 'rf_Bollinger_w10_std1_5_EURUSD_time_M1_20220101_20231231_pr-1_st-2_ta-10_20251216_111408.pkl', 'strategy': 'EURUSD', 'symbol': 'FUNDEDNEXT_STLR2_6K', 'account': 'time', 'bar_type': 'M1', 'bar_size': '20220101_20231231', 'date_range': 'bdad004f', 'config_hash': 'rf_Bollinger_w10_std1_5_EURUSD_time_M1_20220101_20231231_pr-1_st-2_ta-10_20251216_111408.pkl', 'model_type': 'rf', 'strategy_from_file': 'Bollinger', 'symbol_from_file': 'w10', 'bar_type_from_file': 'std1', 'bar_size_from_file': '5', 'date_range_from_file': 'EURUSD'}
# tick:
# {'file_path': 'Models\\Bollinger_w10_std1_5\\EURUSD\\FUNDEDNEXT_STLR2_6K\\tick\\M1\\20220101_20231231\\18f7d38e\\rf_Bollinger_w10_std1_5_EURUSD_tick_M1_20220101_20231231_pr-1_st-2_ta-10_20251216_111829.pkl', 'file_name': 'rf_Bollinger_w10_std1_5_EURUSD_tick_M1_20220101_20231231_pr-1_st-2_ta-10_20251216_111829.pkl', 'strategy': 'EURUSD', 'symbol': 'FUNDEDNEXT_STLR2_6K', 'account': 'tick', 'bar_type': 'M1', 'bar_size': '20220101_20231231', 'date_range': '18f7d38e', 'config_hash': 'rf_Bollinger_w10_std1_5_EURUSD_tick_M1_20220101_20231231_pr-1_st-2_ta-10_20251216_111829.pkl', 'model_type': 'rf', 'strategy_from_file': 'Bollinger', 'symbol_from_file': 'w10', 'bar_type_from_file': 'std1', 'bar_size_from_file': '5', 'date_range_from_file': 'EURUSD'}

# %%
training_results = {}

for k, v in trained_models.items():
    print(k)
    if "time" in k:
        training_results["time"] = list(v.values())[0]
    elif "tick" in k:
        training_results["tick"] = list(v.values())[0]
# Out:
# {"account_name": "FUNDEDNEXT_STLR2_6K", "bar_size": "M1", "bar_type": "time", "price": "mid_price", "train_end": "2023-12-31", "train_start": "2022-01-01"}
# {"account_name": "FUNDEDNEXT_STLR2_6K", "bar_size": "M1", "bar_type": "tick", "price": "mid_price", "train_end": "2023-12-31", "train_start": "2022-01-01"}

# %%
from ensurepip import bootstrap


pipeline = training_results["tick"].pipeline
estimator = clone(pipeline.best_model.steps[-1][1]).set_params(
    n_jobs=None,
    bootstrap=False,
    n_estimators=1,
    max_samples=None,
)
seq_rf_tick = SequentiallyBootstrappedBaggingClassifier(
    samples_info_sets=pipeline.events["t1"],
    price_bars_index=pipeline.bar_data.index,
    estimator=estimator,
    n_estimators=100,
    random_state=7,
    verbose=1,
    )
X, y = pipeline.preprocessed_features, pipeline.events["bin"]
w = pipeline.sample_weight.reindex(y.index)

seq_rf_tick.fit(X, y, w)
winsound.Beep(1000, 1000)
# y_pred = seq_rf_tick.predict()
# Out:
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   2 out of   4 | elapsed:  1.0min remaining:  1.0min
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:  1.2min finished

# %%
from afml.backtest_statistics import (
    analyze_signal_quality,
    calculate_risk_adjusted_metrics,
    compare_strategies,
    generate_summary_report,
    plot_strategy_comparison,
    evaluate_meta_labeling_performance,
)

# %%
# test_start = pd.Timestamp(end_date) + pd.Timedelta(days=1)
# test_end = test_start + pd.Timedelta(weeks=52)
# validation_metrics_by_conf = {}
# confidence_thresholds = np.arange(0.5, 0.61, 0.01)
# bet_sizing_methods = [None, "probability", "budget"]

# for thres in confidence_thresholds:
#     validation_metrics_by_conf.setdefault(thres, {})
#     for k in ["time", "tick"]:
#         pipeline = training_results[k].pipeline
#         validation_metrics_by_conf[thres].setdefault(k, {})
#         for bet_sizing in bet_sizing_methods:
#             validation_metrics, clf_report = get_validation_metrics(test_start, test_end, pipeline, bet_sizing, thres)
#             validation_metrics_by_conf[thres][k][bet_sizing] = (validation_metrics, clf_report)
#             print(f"\n{k}-Bars | Confidence - {thres} | {bet_sizing}".upper())
#             print("=" * 80)
#             print(clf_report)

#     # pprint(validation_metrics_by_conf)
#     # break

#     # comparison = compare_strategies(validation_metrics)
#     # report = generate_summary_report(validation_metrics)
#     # print(report, "\n")

# validation_metrics_by_conf[0.5]["time"][None]
# Out:
# {'strategy_name': 'Bollinger_w10_std1.5',
#  'primary_metrics': {'total_return': 0.051374197006225586,
#   'annualized_return': 0.07991646831702548,
#   'volatility': 0.27293890168822954,
#   'downside_volatility': 0.24699759544245722,
#   'sharpe_ratio': 4.261811775601719,
#   'sortino_ratio': 4.709415179329911,
#   'var_95': nan,
#   'cvar_95': 0,
#   'skewness': nan,
#   'kurtosis': nan,
#   'positive_concentration': 7.832211363755032e-05,
#   'negative_concentration': 0.00014435552608320235,
#   'time_concentration': 0.03472748269981497,
#   'max_drawdown': 0.03996653772103331,
#   'avg_drawdown': 0.003208680245793615,
#   'drawdown_duration': Timedelta('1 days 05:12:17'),
#   'ulcer_index': 0.008219526621080062,
#   'calmar_ratio': 1.9995844742630182,
#   'num_trades': 16149,
#   'trades_per_year': 24436,
#   'win_rate': 0.6484612050281752,
#   'avg_win': 0.00025048407,
#   'avg_loss': 0.0004530138,
#   'best_trade': 0.004404842853546143,
#   'worst_trade': -0.007657408714294434,
#   'profit_factor': 1.0201309,
#   'expectancy': 3.1772707974498803e-06,
#   'kelly_criterion': 0.01268450771642271,
#   'consecutive_wins': 25,
#   'consecutive_losses': 14,
#   'avg_trade_duration': Timedelta('0 days 00:29:18'),
#   'bet_frequency': 16149,
#   'bets_per_year': 16},
#  'meta_metrics': {'total_return': 0.6784079074859619,
#   'annualized_return': 1.2138189096236487,
#   'volatility': 0.24995475435061204,
#   'downside_volatility': 0.26623427600065613,
#   'sharpe_ratio': 88.62693075648909,
#   'sortino_ratio': 83.20762840481267,
#   'var_95': -0.0005734682083129883,
#   'cvar_95': -0.0009986057,
#   'skewness': -3.0864912618303446,
#   'kurtosis': 46.689382547780895,
#   'positive_concentration': 0.00011755023594617651,
#   'negative_concentration': 0.0004536441082321024,
#   'time_concentration': 0.03448706904764465,
#   'max_drawdown': 0.027108853768228136,
#   'avg_drawdown': 0.0009703270643069804,
#   'drawdown_duration': Timedelta('0 days 05:44:24'),
#   'ulcer_index': 0.001858248291714088,
#   'calmar_ratio': 44.77573710793546,
#   'num_trades': 8495,
#   'trades_per_year': 12854,
#   'win_rate': 0.7360800470865215,
#   'avg_win': 0.00024009845,
#   'avg_loss': 0.00043833256,
#   'best_trade': 0.0038666725158691406,
#   'worst_trade': -0.007657408714294434,
#   'profit_factor': 1.5277013,
#   'expectancy': 6.1046972014602e-05,
#   'kelly_criterion': 0.2542580970135375,
#   'consecutive_wins': 26,
#   'consecutive_losses': 7,
#   'avg_trade_duration': Timedelta('0 days 00:29:35'),
#   'bet_frequency': 8496,
#   'bets_per_year': 8,
#   'signal_filter_rate': 0.4738993126509381,
#   'confidence_threshold': 0.5,
#   'actual_trades_per_year': 20413},
#  'primary_returns': time
#  2024-03-28 00:30:00    0.000102
#  2024-03-28 00:40:00    0.000166
#  2024-03-28 00:45:00    0.000139
#  2024-03-28 00:48:00    0.000213
#  2024-03-28 00:58:00    0.000143
#                           ...
#  2024-08-27 03:01:00    0.000143
#  2024-08-27 03:12:00    0.000152
#  2024-08-27 03:22:00    0.000233
#  2024-08-27 03:42:00         NaN
#  2024-08-27 03:55:00    0.000287
#  Name: close, Length: 16149, dtype: float32,
#  'meta_returns': time
#  2024-03-28 00:30:00    0.000102
#  2024-03-28 00:40:00    0.000166
#  2024-03-28 00:45:00    0.000139
#  2024-03-28 00:48:00    0.000213
#  2024-03-28 00:58:00    0.000143
#                           ...
#  2024-08-27 02:43:00    0.000049
#  2024-08-27 03:01:00    0.000143
#  2024-08-27 03:12:00    0.000152
#  2024-08-27 03:22:00    0.000233
#  2024-08-27 03:55:00    0.000287
#  Length: 8495, dtype: float32,
#  'total_primary_signals': 16149,
#  'filtered_signals': 8496,
#  'symbol': 'EURUSD',
#  'bar_size': 'M1',
#  'bar_type': 'time'}

# %%
print("\nStrategy Configuration")
print("-" * 45)
print(pd.Series(config), "\n")
# Out:
# Strategy Configuration
# ---------------------------------------------
# strategy                 Bollinger_w10_std1.5
# symbol                                 EURUSD
# training_start                     2022-01-01
# training_end                       2023-12-31
# account_name              FUNDEDNEXT_STLR2_6K
# bar_type                                 tick
# bar_size                                   M1
# price                               mid_price
# target_lookback                            10
# profit_target                               1
# stop_loss                                   2
# max_holding_period                {'days': 1}
# min_ret                                     0
# vertical_barrier_zero                    True
# filter_as_series                        False
# dtype: object

# %%
from afml.backtest_statistics.meta_labeling_analysis import get_validation_metrics


test_start = pd.Timestamp(end_date) + pd.Timedelta(days=1)
test_end = test_start + pd.Timedelta(weeks=52)
bet_sizing_methods = {k: None for k in [None, "probability", "budget"]}
validation_metrics_by_bar_type = {}

for bet_sizing in bet_sizing_methods.keys():
    for k in ["time", "tick"]:
        pipeline = training_results[k].pipeline
        validation_metrics = get_validation_metrics(
            test_start,
            test_end,
            pipeline,
            bet_sizing=bet_sizing,
            confidence_threshold=0.5,
            )
        validation_metrics_by_bar_type[k] = validation_metrics
        report = generate_summary_report(validation_metrics)
        print("=" * 80)
        print(f"{k}-bars | bet-sizing - {bet_sizing}".upper())
        print("=" * 80)
        print(validation_metrics["classification_report"], "\n")
        print(report)
    bet_sizing_methods[bet_sizing] = validation_metrics_by_bar_type.copy()
# Out:
# 2025-12-16 21:28:06 | afml.cache.unified_cache_system | DEBUG | Cache HIT: afml.production.model_development.load_and_prepare_training_data (key: 3a0ef7eb...)
# 2025-12-16 21:28:06 | afml.cache.unified_cache_system | DEBUG | Cache HIT: afml.production.model_development.generate_events_triple_barrier (key: 85de43f3...)
# 2025-12-16 21:28:06 | afml.cache.unified_cache_system | DEBUG | Cache HIT: afml.production.model_development.calculate_rolling_metrics (key: 62bc5b4d...)
# 2025-12-16 21:28:07 | afml.cache.unified_cache_system | DEBUG | Cache HIT: afml.production.model_development.create_feature_engineering_pipeline (key: 0b59e90f...)
# 2025-12-16 21:28:09 | afml.backtest_statistics.meta_labeling_analysis | INFO | Bet Sizing Method: None | Confidence Threshold: 0.5
# 2025-12-16 21:28:09 | afml.backtest_statistics.performance_analysis | DEBUG | Inferred timeframe to be 0 days 00:01:00.
# 2025-12-16 21:28:09 | afml.backtest_statistics.performance_analysis | DEBUG | Inferred timeframe to be 0 days 00:01:00.
# ================================================================================
# TIME-BARS | BET-SIZING - NONE
# ================================================================================
#               precision    recall  f1-score   support
#
#            0       0.45      0.60      0.52      5681
#            1       0.74      0.60      0.66     10468
#
#     accuracy                           0.60     16149
#    macro avg       0.59      0.60      0.59     16149
# weighted avg       0.63      0.60      0.61     16149
#
#
# ================================================================================
# META-LABELING PERFORMANCE REPORT: Bollinger_w10_std1.5
# ================================================================================
#
# SIGNAL FILTERING
# ----------------------------------------
# Total Primary Signals:    16,149
# Accepted by Meta Model:   8,496
# Rejected by Meta Model:   7,654
# Filter Rate:              47.4%
# Confidence Threshold:     0.50
#
# PERFORMANCE COMPARISON
# ----------------------------------------
# Total Return............. Primary: 5.14%      Meta: 67.84%     (+1,220.5%) ✅
# Annualized Return........ Primary: 7.99%      Meta: 121.38%    (+1,418.9%) ✅
# Sharpe Ratio............. Primary: 4.26       Meta: 88.63      (+1,979.6%) ✅
# Sortino Ratio............ Primary: 4.71       Meta: 83.21      (+1,666.8%) ✅
# Calmar Ratio............. Primary: 2.00       Meta: 44.78      (+2,139.3%) ✅
# Max Drawdown............. Primary: 4.00%      Meta: 2.71%      (-32.2%) ✅
# Volatility............... Primary: 27.29%     Meta: 25.00%     (-8.4%) ✅
# Win Rate................. Primary: 64.8%      Meta: 73.6%      (+13.5%) ✅
# Profit Factor............ Primary: 1.02       Meta: 1.53       (+49.8%) ✅
# Kelly Criterion.......... Primary: 1.27%      Meta: 25.43%     (+1,904.5%) ✅
#
# SIGNAL QUALITY ANALYSIS
# ----------------------------------------
# Accepted Signal Win Rate: 73.6%
# Rejected Signal Win Rate: 55.1%
# Filter Precision:         73.6%
# Avoided Losses:           44.9%
#
# TRADE STATISTICS
# ----------------------------------------
# Number of Trades:         Primary: 16,149           Meta: 8,495
# Avg Trade Duration:       Primary: 0 days 00:29:18  Meta: 0 days 00:29:35
# Best Trade:               Primary: 0.44%            Meta: 0.39%
# Worst Trade:              Primary: -0.77%           Meta: -0.77%
# Consecutive Wins:         Primary: 25               Meta: 26
# Consecutive Losses:       Primary: 14               Meta: 7
#
# KEY INSIGHTS
# ----------------------------------------
# ✅ Meta-labeling improved Sharpe ratio by 1,979.6%
# ✅ Reduced maximum drawdown by 32.2%
# ✅ Improved win rate by 8.8% percentage points
#
# ================================================================================
# 2025-12-16 21:28:09 | afml.cache.unified_cache_system | DEBUG | Cache HIT: afml.production.model_development.load_and_prepare_training_data (key: eba6cfb2...)
# 2025-12-16 21:28:09 | afml.cache.unified_cache_system | DEBUG | Cache HIT: afml.production.model_development.generate_events_triple_barrier (key: 660b757c...)
# 2025-12-16 21:28:09 | afml.cache.unified_cache_system | DEBUG | Cache HIT: afml.production.model_development.calculate_rolling_metrics (key: c2448592...)
# 2025-12-16 21:28:10 | afml.cache.unified_cache_system | DEBUG | Cache HIT: afml.production.model_development.create_feature_engineering_pipeline (key: 0ec4a6f2...)
# 2025-12-16 21:28:11 | afml.backtest_statistics.meta_labeling_analysis | INFO | Bet Sizing Method: None | Confidence Threshold: 0.5
# 2025-12-16 21:28:11 | afml.backtest_statistics.performance_analysis | DEBUG | Inferred timeframe from median delta as 0 days 00:00:34.022000.
# 2025-12-16 21:28:11 | afml.backtest_statistics.performance_analysis | DEBUG | Inferred timeframe from median delta as 0 days 00:00:34.022000.
# ================================================================================
# TICK-BARS | BET-SIZING - NONE
# ================================================================================
#               precision    recall  f1-score   support
#
#            0       0.46      0.60      0.52     10759
#            1       0.73      0.61      0.66     19390
#
#     accuracy                           0.60     30149
#    macro avg       0.59      0.60      0.59     30149
# weighted avg       0.63      0.60      0.61     30149
#
#
# ================================================================================
# META-LABELING PERFORMANCE REPORT: Bollinger_w10_std1.5
# ================================================================================
#
# SIGNAL FILTERING
# ----------------------------------------
# Total Primary Signals:    30,149
# Accepted by Meta Model:   16,088
# Rejected by Meta Model:   14,061
# Filter Rate:              46.6%
# Confidence Threshold:     0.50
#
# PERFORMANCE COMPARISON
# ----------------------------------------
# Total Return............. Primary: 18.79%     Meta: 156.69%    (+733.7%) ✅
# Annualized Return........ Primary: 28.10%     Meta: 287.90%    (+924.6%) ✅
# Sharpe Ratio............. Primary: 13.79      Meta: 152.90     (+1,008.9%) ✅
# Sortino Ratio............ Primary: 18.36      Meta: 191.42     (+942.7%) ✅
# Calmar Ratio............. Primary: 5.03       Meta: 180.10     (+3,478.6%) ✅
# Max Drawdown............. Primary: 5.58%      Meta: 1.60%      (-71.4%) ✅
# Volatility............... Primary: 26.77%     Meta: 24.55%     (-8.3%) ✅
# Win Rate................. Primary: 64.3%      Meta: 73.1%      (+13.7%) ✅
# Profit Factor............ Primary: 1.04       Meta: 1.63       (+55.9%) ✅
# Kelly Criterion.......... Primary: 2.76%      Meta: 28.24%     (+921.7%) ✅
#
# SIGNAL QUALITY ANALYSIS
# ----------------------------------------
# Accepted Signal Win Rate: 73.1%
# Rejected Signal Win Rate: 54.3%
# Filter Precision:         73.1%
# Avoided Losses:           45.7%
# T-Test P-Value:           0.0000
# Statistically Better:     Yes
#
# TRADE STATISTICS
# ----------------------------------------
# Number of Trades:         Primary: 30,149           Meta: 16,088
# Avg Trade Duration:       Primary: 0 days 00:18:04  Meta: 0 days 00:17:51
# Best Trade:               Primary: 0.41%            Meta: 0.39%
# Worst Trade:              Primary: -0.70%           Meta: -0.49%
# Consecutive Wins:         Primary: 20               Meta: 22
# Consecutive Losses:       Primary: 17               Meta: 7
#
# KEY INSIGHTS
# ----------------------------------------
# ✅ Meta-labeling improved Sharpe ratio by 1,008.9%
# ✅ Reduced maximum drawdown by 71.4%
# ✅ Improved win rate by 8.8% percentage points
#
# ================================================================================
# 2025-12-16 21:28:12 | afml.cache.unified_cache_system | DEBUG | Cache HIT: afml.production.model_development.load_and_prepare_training_data (key: 3a0ef7eb...)
# 2025-12-16 21:28:12 | afml.cache.unified_cache_system | DEBUG | Cache HIT: afml.production.model_development.generate_events_triple_barrier (key: 85de43f3...)
# 2025-12-16 21:28:12 | afml.cache.unified_cache_system | DEBUG | Cache HIT: afml.production.model_development.calculate_rolling_metrics (key: 62bc5b4d...)
# 2025-12-16 21:28:12 | afml.cache.unified_cache_system | DEBUG | Cache HIT: afml.production.model_development.create_feature_engineering_pipeline (key: 0b59e90f...)
# 2025-12-16 21:28:13 | afml.backtest_statistics.meta_labeling_analysis | INFO | Bet Sizing Method: Probability | Confidence Threshold: 0.5
# 2025-12-16 21:28:13 | afml.backtest_statistics.performance_analysis | DEBUG | Inferred timeframe to be 0 days 00:01:00.
# 2025-12-16 21:28:13 | afml.backtest_statistics.performance_analysis | DEBUG | Inferred timeframe to be 0 days 00:01:00.
# ================================================================================
# TIME-BARS | BET-SIZING - PROBABILITY
# ================================================================================
#               precision    recall  f1-score   support
#
#            0       0.45      0.60      0.52      5681
#            1       0.74      0.60      0.66     10468
#
#     accuracy                           0.60     16149
#    macro avg       0.59      0.60      0.59     16149
# weighted avg       0.63      0.60      0.61     16149
#
#
# ================================================================================
# META-LABELING PERFORMANCE REPORT: Bollinger_w10_std1.5
# ================================================================================
#
# SIGNAL FILTERING
# ----------------------------------------
# Total Primary Signals:    16,149
# Accepted by Meta Model:   8,496
# Rejected by Meta Model:   7,654
# Filter Rate:              47.4%
# Confidence Threshold:     0.50
#
# PERFORMANCE COMPARISON
# ----------------------------------------
# Total Return............. Primary: 5.14%      Meta: 3.43%      (-33.3%) ❌
# Annualized Return........ Primary: 7.99%      Meta: 5.31%      (-33.6%) ❌
# Sharpe Ratio............. Primary: 4.26       Meta: 110.67     (+2,496.9%) ✅
# Sortino Ratio............ Primary: 4.71       Meta: 106.54     (+2,162.3%) ✅
# Calmar Ratio............. Primary: 2.00       Meta: 75.47      (+3,674.1%) ✅
# Max Drawdown............. Primary: 4.00%      Meta: 0.07%      (-98.2%) ✅
# Volatility............... Primary: 27.29%     Meta: 1.30%      (-95.2%) ✅
# Win Rate................. Primary: 64.8%      Meta: 73.6%      (+13.5%) ✅
# Profit Factor............ Primary: 1.02       Meta: 1.77       (+73.3%) ✅
# Kelly Criterion.......... Primary: 1.27%      Meta: 31.98%     (+2,420.8%) ✅
#
# SIGNAL QUALITY ANALYSIS
# ----------------------------------------
# Accepted Signal Win Rate: 73.6%
# Rejected Signal Win Rate: 55.1%
# Filter Precision:         73.6%
# Avoided Losses:           44.9%
#
# TRADE STATISTICS
# ----------------------------------------
# Number of Trades:         Primary: 16,149           Meta: 8,495
# Avg Trade Duration:       Primary: 0 days 00:29:18  Meta: 0 days 00:29:35
# Best Trade:               Primary: 0.44%            Meta: 0.03%
# Worst Trade:              Primary: -0.77%           Meta: -0.03%
# Consecutive Wins:         Primary: 25               Meta: 26
# Consecutive Losses:       Primary: 14               Meta: 7
#
# KEY INSIGHTS
# ----------------------------------------
# ✅ Meta-labeling improved Sharpe ratio by 2,496.9%
# ✅ Reduced maximum drawdown by 98.2%
# ✅ Improved win rate by 8.8% percentage points
#
# ================================================================================
# 2025-12-16 21:28:13 | afml.cache.unified_cache_system | DEBUG | Cache HIT: afml.production.model_development.load_and_prepare_training_data (key: eba6cfb2...)
# 2025-12-16 21:28:13 | afml.cache.unified_cache_system | DEBUG | Cache HIT: afml.production.model_development.generate_events_triple_barrier (key: 660b757c...)
# 2025-12-16 21:28:13 | afml.cache.unified_cache_system | DEBUG | Cache HIT: afml.production.model_development.calculate_rolling_metrics (key: c2448592...)
# 2025-12-16 21:28:13 | afml.cache.unified_cache_system | DEBUG | Cache HIT: afml.production.model_development.create_feature_engineering_pipeline (key: 0ec4a6f2...)
# 2025-12-16 21:28:15 | afml.backtest_statistics.meta_labeling_analysis | INFO | Bet Sizing Method: Probability | Confidence Threshold: 0.5
# 2025-12-16 21:28:15 | afml.backtest_statistics.performance_analysis | DEBUG | Inferred timeframe from median delta as 0 days 00:00:34.022000.
# 2025-12-16 21:28:15 | afml.backtest_statistics.performance_analysis | DEBUG | Inferred timeframe from median delta as 0 days 00:00:34.022000.
# ================================================================================
# TICK-BARS | BET-SIZING - PROBABILITY
# ================================================================================
#               precision    recall  f1-score   support
#
#            0       0.46      0.60      0.52     10759
#            1       0.73      0.61      0.66     19390
#
#     accuracy                           0.60     30149
#    macro avg       0.59      0.60      0.59     30149
# weighted avg       0.63      0.60      0.61     30149
#
#
# ================================================================================
# META-LABELING PERFORMANCE REPORT: Bollinger_w10_std1.5
# ================================================================================
#
# SIGNAL FILTERING
# ----------------------------------------
# Total Primary Signals:    30,149
# Accepted by Meta Model:   16,088
# Rejected by Meta Model:   14,061
# Filter Rate:              46.6%
# Confidence Threshold:     0.50
#
# PERFORMANCE COMPARISON
# ----------------------------------------
# Total Return............. Primary: 18.79%     Meta: 13.34%     (-29.0%) ❌
# Annualized Return........ Primary: 28.10%     Meta: 19.73%     (-29.8%) ❌
# Sharpe Ratio............. Primary: 13.79      Meta: 161.72     (+1,072.8%) ✅
# Sortino Ratio............ Primary: 18.36      Meta: 164.04     (+793.5%) ✅
# Calmar Ratio............. Primary: 5.03       Meta: 104.93     (+1,985.1%) ✅
# Max Drawdown............. Primary: 5.58%      Meta: 0.19%      (-96.6%) ✅
# Volatility............... Primary: 26.77%     Meta: 3.08%      (-88.5%) ✅
# Win Rate................. Primary: 64.3%      Meta: 73.1%      (+13.7%) ✅
# Profit Factor............ Primary: 1.04       Meta: 1.93       (+85.0%) ✅
# Kelly Criterion.......... Primary: 2.76%      Meta: 35.31%     (+1,177.4%) ✅
#
# SIGNAL QUALITY ANALYSIS
# ----------------------------------------
# Accepted Signal Win Rate: 73.1%
# Rejected Signal Win Rate: 54.3%
# Filter Precision:         73.1%
# Avoided Losses:           45.7%
# T-Test P-Value:           0.0000
# Statistically Better:     Yes
#
# TRADE STATISTICS
# ----------------------------------------
# Number of Trades:         Primary: 30,149           Meta: 16,088
# Avg Trade Duration:       Primary: 0 days 00:18:04  Meta: 0 days 00:17:51
# Best Trade:               Primary: 0.41%            Meta: 0.06%
# Worst Trade:              Primary: -0.70%           Meta: -0.08%
# Consecutive Wins:         Primary: 20               Meta: 22
# Consecutive Losses:       Primary: 17               Meta: 7
#
# KEY INSIGHTS
# ----------------------------------------
# ✅ Meta-labeling improved Sharpe ratio by 1,072.8%
# ✅ Reduced maximum drawdown by 96.6%
# ✅ Improved win rate by 8.8% percentage points
#
# ================================================================================
# 2025-12-16 21:28:15 | afml.cache.unified_cache_system | DEBUG | Cache HIT: afml.production.model_development.load_and_prepare_training_data (key: 3a0ef7eb...)
# 2025-12-16 21:28:16 | afml.cache.unified_cache_system | DEBUG | Cache HIT: afml.production.model_development.generate_events_triple_barrier (key: 85de43f3...)
# 2025-12-16 21:28:16 | afml.cache.unified_cache_system | DEBUG | Cache HIT: afml.production.model_development.calculate_rolling_metrics (key: 62bc5b4d...)
# 2025-12-16 21:28:16 | afml.cache.unified_cache_system | DEBUG | Cache HIT: afml.production.model_development.create_feature_engineering_pipeline (key: 0b59e90f...)
# 2025-12-16 21:28:17 | afml.backtest_statistics.meta_labeling_analysis | INFO | Bet Sizing Method: Budget | Confidence Threshold: 0.5
# 2025-12-16 21:28:17 | afml.backtest_statistics.performance_analysis | DEBUG | Inferred timeframe to be 0 days 00:01:00.
# 2025-12-16 21:28:17 | afml.backtest_statistics.performance_analysis | DEBUG | Inferred timeframe to be 0 days 00:01:00.
# ================================================================================
# TIME-BARS | BET-SIZING - BUDGET
# ================================================================================
#               precision    recall  f1-score   support
#
#            0       0.45      0.60      0.52      5681
#            1       0.74      0.60      0.66     10468
#
#     accuracy                           0.60     16149
#    macro avg       0.59      0.60      0.59     16149
# weighted avg       0.63      0.60      0.61     16149
#
#
# ================================================================================
# META-LABELING PERFORMANCE REPORT: Bollinger_w10_std1.5
# ================================================================================
#
# SIGNAL FILTERING
# ----------------------------------------
# Total Primary Signals:    16,149
# Accepted by Meta Model:   8,496
# Rejected by Meta Model:   7,654
# Filter Rate:              47.4%
# Confidence Threshold:     0.50
#
# PERFORMANCE COMPARISON
# ----------------------------------------
# Total Return............. Primary: 5.14%      Meta: 13.13%     (+155.5%) ✅
# Annualized Return........ Primary: 7.99%      Meta: 20.84%     (+160.7%) ✅
# Sharpe Ratio............. Primary: 4.26       Meta: 75.58      (+1,673.4%) ✅
# Sortino Ratio............ Primary: 4.71       Meta: 54.04      (+1,047.4%) ✅
# Calmar Ratio............. Primary: 2.00       Meta: 14.93      (+646.5%) ✅
# Max Drawdown............. Primary: 4.00%      Meta: 1.40%      (-65.1%) ✅
# Volatility............... Primary: 27.29%     Meta: 6.97%      (-74.4%) ✅
# Win Rate................. Primary: 64.8%      Meta: 61.0%      (-5.9%) ❌
# Profit Factor............ Primary: 1.02       Meta: 1.68       (+64.5%) ✅
# Kelly Criterion.......... Primary: 1.27%      Meta: 0.30%      (-76.0%) ❌
#
# SIGNAL QUALITY ANALYSIS
# ----------------------------------------
# Accepted Signal Win Rate: 61.0%
# Rejected Signal Win Rate: 55.1%
# Filter Precision:         61.0%
# Avoided Losses:           44.9%
#
# TRADE STATISTICS
# ----------------------------------------
# Number of Trades:         Primary: 16,149           Meta: 8,495
# Avg Trade Duration:       Primary: 0 days 00:29:18  Meta: 0 days 00:29:35
# Best Trade:               Primary: 0.44%            Meta: 0.15%
# Worst Trade:              Primary: -0.77%           Meta: -0.35%
# Consecutive Wins:         Primary: 25               Meta: 19
# Consecutive Losses:       Primary: 14               Meta: 11
#
# KEY INSIGHTS
# ----------------------------------------
# ✅ Meta-labeling improved Sharpe ratio by 1,673.4%
# ✅ Reduced maximum drawdown by 65.1%
#
# ================================================================================
# 2025-12-16 21:28:17 | afml.cache.unified_cache_system | DEBUG | Cache HIT: afml.production.model_development.load_and_prepare_training_data (key: eba6cfb2...)
# 2025-12-16 21:28:17 | afml.cache.unified_cache_system | DEBUG | Cache HIT: afml.production.model_development.generate_events_triple_barrier (key: 660b757c...)
# 2025-12-16 21:28:17 | afml.cache.unified_cache_system | DEBUG | Cache HIT: afml.production.model_development.calculate_rolling_metrics (key: c2448592...)
# 2025-12-16 21:28:17 | afml.cache.unified_cache_system | DEBUG | Cache HIT: afml.production.model_development.create_feature_engineering_pipeline (key: 0ec4a6f2...)
# 2025-12-16 21:28:19 | afml.backtest_statistics.meta_labeling_analysis | INFO | Bet Sizing Method: Budget | Confidence Threshold: 0.5
# 2025-12-16 21:28:19 | afml.backtest_statistics.performance_analysis | DEBUG | Inferred timeframe from median delta as 0 days 00:00:34.022000.
# 2025-12-16 21:28:19 | afml.backtest_statistics.performance_analysis | DEBUG | Inferred timeframe from median delta as 0 days 00:00:34.022000.
# ================================================================================
# TICK-BARS | BET-SIZING - BUDGET
# ================================================================================
#               precision    recall  f1-score   support
#
#            0       0.46      0.60      0.52     10759
#            1       0.73      0.61      0.66     19390
#
#     accuracy                           0.60     30149
#    macro avg       0.59      0.60      0.59     30149
# weighted avg       0.63      0.60      0.61     30149
#
#
# ================================================================================
# META-LABELING PERFORMANCE REPORT: Bollinger_w10_std1.5
# ================================================================================
#
# SIGNAL FILTERING
# ----------------------------------------
# Total Primary Signals:    30,149
# Accepted by Meta Model:   16,088
# Rejected by Meta Model:   14,061
# Filter Rate:              46.6%
# Confidence Threshold:     0.50
#
# PERFORMANCE COMPARISON
# ----------------------------------------
# Total Return............. Primary: 18.79%     Meta: 24.89%     (+32.5%) ✅
# Annualized Return........ Primary: 28.10%     Meta: 37.67%     (+34.0%) ✅
# Sharpe Ratio............. Primary: 13.79      Meta: 145.01     (+951.6%) ✅
# Sortino Ratio............ Primary: 18.36      Meta: 137.62     (+649.6%) ✅
# Calmar Ratio............. Primary: 5.03       Meta: 63.74      (+1,166.4%) ✅
# Max Drawdown............. Primary: 5.58%      Meta: 0.59%      (-89.4%) ✅
# Volatility............... Primary: 26.77%     Meta: 6.10%      (-77.2%) ✅
# Win Rate................. Primary: 64.3%      Meta: 68.9%      (+7.1%) ✅
# Profit Factor............ Primary: 1.04       Meta: 1.88       (+79.9%) ✅
# Kelly Criterion.......... Primary: 2.76%      Meta: 32.26%     (+1,067.2%) ✅
#
# SIGNAL QUALITY ANALYSIS
# ----------------------------------------
# Accepted Signal Win Rate: 68.9%
# Rejected Signal Win Rate: 54.3%
# Filter Precision:         68.9%
# Avoided Losses:           45.7%
# T-Test P-Value:           0.0000
# Statistically Better:     Yes
#
# TRADE STATISTICS
# ----------------------------------------
# Number of Trades:         Primary: 30,149           Meta: 16,088
# Avg Trade Duration:       Primary: 0 days 00:18:04  Meta: 0 days 00:17:51
# Best Trade:               Primary: 0.41%            Meta: 0.11%
# Worst Trade:              Primary: -0.70%           Meta: -0.21%
# Consecutive Wins:         Primary: 20               Meta: 24
# Consecutive Losses:       Primary: 17               Meta: 11
#
# KEY INSIGHTS
# ----------------------------------------
# ✅ Meta-labeling improved Sharpe ratio by 951.6%
# ✅ Reduced maximum drawdown by 89.4%
# ✅ Improved win rate by 4.6% percentage points
#
# ================================================================================

# %%
bet_sizing = None
validation_metrics_by_bar_type = bet_sizing_methods[bet_sizing]
comp_fig = plot_strategy_comparison(validation_metrics_by_bar_type["time"])

# %%
from afml.backtest_statistics.meta_labeling_analysis import (
    generate_complete_meta_labeling_report,
    plot_strategy_comparison,
)
validation_metrics = validation_metrics_by_bar_type["time"].copy()
dirpath = Path(
    "Meta_Labeling_Analysis", validation_metrics["strategy_name"],
    validation_metrics["symbol"], validation_metrics["bar_size"]
    )

meta_report = generate_complete_meta_labeling_report(
    validation_metrics_by_bar_type,
    output_dir=dirpath,
    filename=f"meta_labeling_analysis_report_bet_sizing_{bet_sizing}".lower()
)
# Out:
# Reloading 'afml.backtest_statistics.meta_labeling_analysis'.
# 🔍 Generating meta-labeling analysis report...

# %% [markdown]
# #### Export Model to ONXX

# %%
from afml.production.model_export import export_model_to_onnx

model_path = Path(r"C:\Users\JoeN\Documents\GitHub\Machine-Learning-Blueprint\models")
fname = f"bollinger_meta_model_{symbol}_{config['bar_type']}_{config['bar_size']}.onxx".lower()
model_path = model_path / fname
export_model_to_onnx(
    best_model.named_steps["clf"],
    feature_names=model_features,
    output_path=model_path,
    metadata=config,
)
# Out:
# ======================================================================
# ONNX EXPORT PIPELINE
# ======================================================================
#
# [Step 1/5] Preparing metadata...
# ✓ Model type: RandomForestClassifier
# ✓ Features: 74
# ✓ Version: 1.0
#
# [Step 2/5] Converting to ONNX format...
# ✓ Conversion successful
# ✓ ONNX opset: 12 (MQL5 compatible)
#
# [Step 3/5] Saving ONNX model...
# ✓ Saved to: C:\Users\JoeN\Documents\GitHub\Machine-Learning-Blueprint\models\bollinger_meta_model_eurusd_tick_m1.onxx
# ✓ File size: 0.16 MB
#
# [Step 4/5] Validating ONNX model...
# ✓ ONNX model structure valid
#
# [Step 5/5] Comparing Python vs ONNX predictions...
#
# Generating test data...
# Computing Python predictions...
# Computing ONNX predictions...
#
# ✓ ONNX returned 2 output(s)
#   Output 0: shape=(1000,), dtype=int64
#     Sample values: 1
#   Output 1: shape=(1000, 2), dtype=float32
#     Sample values: [0.48720157 0.5127984 ]
#
# ✓ Using output 1 (probabilities)
# ✓ Extracted positive class probabilities from shape (1000, 2)
#
# Prediction Comparison (1000 samples):
#   • Max difference:  1.52e-07
#   • Mean difference: 4.91e-08
#   • Std difference:  3.30e-08
#
# ✅ VALIDATION PASSED - Predictions match within tolerance (1.00e-05)
#
# Sample Predictions (first 5):
# Index    Python       ONNX         Diff
# --------------------------------------------------
# 0        0.512798     0.512798     8.19e-08
# 1        0.459688     0.459688     5.50e-08
# 2        0.451748     0.451748     7.06e-08
# 3        0.478857     0.478857     6.04e-08
# 4        0.460223     0.460223     6.36e-08
#
# ======================================================================
# ✅ EXPORT SUCCESSFUL - Model ready for MQL5 deployment
# ======================================================================
# True

# %% [markdown]
# ### Cache Analysis

# %%
# from afml.cache import clear_afml_cache

# clear_afml_cache()

# %%
from afml.cache import get_cache_size_info, print_cache_health

print_cache_health()
# Out:
# 2025-12-01 14:08:52.198 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:444 - Looking for cache in: C:\Users\JoeN\AppData\Local\afml\afml\Cache\joblib_cache
# 2025-12-01 14:08:52.203 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:459 - Searching for patterns: ['afml_production_model_development_load_and_prepare_training_data', 'load_and_prepare_training_data']
# 2025-12-01 14:08:52.286 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: func_code.py - 662 bytes
# 2025-12-01 14:08:52.288 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 263 bytes
# 2025-12-01 14:08:52.290 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 4437512 bytes
# 2025-12-01 14:08:52.305 | INFO     | afml.cache.cache_monitoring:_get_function_cache_size:487 - Cache size for afml.production.model_development.load_and_prepare_training_data: 4.23 MB (3 files)
# 2025-12-01 14:08:52.306 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:444 - Looking for cache in: C:\Users\JoeN\AppData\Local\afml\afml\Cache\joblib_cache
# 2025-12-01 14:08:52.308 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:459 - Searching for patterns: ['afml_production_model_development_create_feature_engineering_pipeline', 'create_feature_engineering_pipeline']
# 2025-12-01 14:08:52.376 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: func_code.py - 278 bytes
# 2025-12-01 14:08:52.378 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1674 bytes
# 2025-12-01 14:08:52.380 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 31733899 bytes
# 2025-12-01 14:08:52.408 | INFO     | afml.cache.cache_monitoring:_get_function_cache_size:487 - Cache size for afml.production.model_development.create_feature_engineering_pipeline: 30.27 MB (3 files)
# 2025-12-01 14:08:52.409 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:444 - Looking for cache in: C:\Users\JoeN\AppData\Local\afml\afml\Cache\joblib_cache
# 2025-12-01 14:08:52.411 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:459 - Searching for patterns: ['afml_strategies_bollinger_features_create_bollinger_features', 'create_bollinger_features']
# 2025-12-01 14:08:52.485 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: func_code.py - 2700 bytes
# 2025-12-01 14:08:52.487 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1582 bytes
# 2025-12-01 14:08:52.490 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 31733899 bytes
# 2025-12-01 14:08:52.494 | INFO     | afml.cache.cache_monitoring:_get_function_cache_size:487 - Cache size for afml.strategies.bollinger_features.create_bollinger_features: 30.27 MB (3 files)
# 2025-12-01 14:08:52.495 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:444 - Looking for cache in: C:\Users\JoeN\AppData\Local\afml\afml\Cache\joblib_cache
# 2025-12-01 14:08:52.497 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:459 - Searching for patterns: ['afml_production_model_development_generate_events_triple_barrier', 'generate_events_triple_barrier']
# 2025-12-01 14:08:52.663 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: func_code.py - 1131 bytes
# 2025-12-01 14:08:52.666 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1791 bytes
# 2025-12-01 14:08:52.670 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 339686 bytes
# 2025-12-01 14:08:52.673 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1790 bytes
# 2025-12-01 14:08:52.674 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 339454 bytes
# 2025-12-01 14:08:52.677 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1791 bytes
# 2025-12-01 14:08:52.679 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 339738 bytes
# 2025-12-01 14:08:52.686 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1790 bytes
# 2025-12-01 14:08:52.688 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 339622 bytes
# 2025-12-01 14:08:52.692 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1790 bytes
# 2025-12-01 14:08:52.696 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 339738 bytes
# 2025-12-01 14:08:52.704 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1792 bytes
# 2025-12-01 14:08:52.710 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 339558 bytes
# 2025-12-01 14:08:52.718 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1791 bytes
# 2025-12-01 14:08:52.720 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 339738 bytes
# 2025-12-01 14:08:52.723 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1791 bytes
# 2025-12-01 14:08:52.725 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 339738 bytes
# 2025-12-01 14:08:52.728 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1791 bytes
# 2025-12-01 14:08:52.730 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 339738 bytes
# 2025-12-01 14:08:52.735 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1789 bytes
# 2025-12-01 14:08:52.738 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 339738 bytes
# 2025-12-01 14:08:52.742 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1791 bytes
# 2025-12-01 14:08:52.746 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 339686 bytes
# 2025-12-01 14:08:52.779 | INFO     | afml.cache.cache_monitoring:_get_function_cache_size:487 - Cache size for afml.production.model_development.generate_events_triple_barrier: 3.58 MB (23 files)
# 2025-12-01 14:08:52.784 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:444 - Looking for cache in: C:\Users\JoeN\AppData\Local\afml\afml\Cache\joblib_cache
# 2025-12-01 14:08:52.786 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:459 - Searching for patterns: ['afml_production_model_development_compute_sample_weights_time_decay', 'compute_sample_weights_time_decay']
# 2025-12-01 14:08:52.806 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: func_code.py - 854 bytes
# 2025-12-01 14:08:52.810 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1549 bytes
# 2025-12-01 14:08:52.815 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 318953 bytes
# 2025-12-01 14:08:52.825 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1548 bytes
# 2025-12-01 14:08:52.837 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319249 bytes
# 2025-12-01 14:08:52.844 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1548 bytes
# 2025-12-01 14:08:52.851 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319249 bytes
# 2025-12-01 14:08:52.855 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1547 bytes
# 2025-12-01 14:08:52.857 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319169 bytes
# 2025-12-01 14:08:52.861 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1549 bytes
# 2025-12-01 14:08:52.864 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319249 bytes
# 2025-12-01 14:08:52.867 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1548 bytes
# 2025-12-01 14:08:52.872 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319041 bytes
# 2025-12-01 14:08:52.876 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1549 bytes
# 2025-12-01 14:08:52.881 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319249 bytes
# 2025-12-01 14:08:52.886 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1548 bytes
# 2025-12-01 14:08:52.890 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319169 bytes
# 2025-12-01 14:08:52.893 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1549 bytes
# 2025-12-01 14:08:52.896 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319249 bytes
# 2025-12-01 14:08:52.901 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1547 bytes
# 2025-12-01 14:08:52.904 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 318953 bytes
# 2025-12-01 14:08:52.912 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1547 bytes
# 2025-12-01 14:08:52.914 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319249 bytes
# 2025-12-01 14:08:52.919 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1549 bytes
# 2025-12-01 14:08:52.923 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319169 bytes
# 2025-12-01 14:08:52.926 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1548 bytes
# 2025-12-01 14:08:52.931 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319249 bytes
# 2025-12-01 14:08:52.936 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1548 bytes
# 2025-12-01 14:08:52.938 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319249 bytes
# 2025-12-01 14:08:52.942 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1547 bytes
# 2025-12-01 14:08:52.948 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319041 bytes
# 2025-12-01 14:08:52.958 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1548 bytes
# 2025-12-01 14:08:52.964 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319249 bytes
# 2025-12-01 14:08:52.969 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1549 bytes
# 2025-12-01 14:08:52.971 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319249 bytes
# 2025-12-01 14:08:52.975 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1549 bytes
# 2025-12-01 14:08:52.980 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319105 bytes
# 2025-12-01 14:08:52.985 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1548 bytes
# 2025-12-01 14:08:52.991 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319249 bytes
# 2025-12-01 14:08:53.002 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1548 bytes
# 2025-12-01 14:08:53.008 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319249 bytes
# 2025-12-01 14:08:53.011 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1548 bytes
# 2025-12-01 14:08:53.019 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319249 bytes
# 2025-12-01 14:08:53.023 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1547 bytes
# 2025-12-01 14:08:53.026 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319249 bytes
# 2025-12-01 14:08:53.036 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1548 bytes
# 2025-12-01 14:08:53.039 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 318953 bytes
# 2025-12-01 14:08:53.042 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1547 bytes
# 2025-12-01 14:08:53.045 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319105 bytes
# 2025-12-01 14:08:53.051 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1548 bytes
# 2025-12-01 14:08:53.056 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319041 bytes
# 2025-12-01 14:08:53.062 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1547 bytes
# 2025-12-01 14:08:53.072 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319249 bytes
# 2025-12-01 14:08:53.078 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1548 bytes
# 2025-12-01 14:08:53.081 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319249 bytes
# 2025-12-01 14:08:53.091 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1547 bytes
# 2025-12-01 14:08:53.094 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319169 bytes
# 2025-12-01 14:08:53.097 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1548 bytes
# 2025-12-01 14:08:53.102 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319249 bytes
# 2025-12-01 14:08:53.106 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1547 bytes
# 2025-12-01 14:08:53.108 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319041 bytes
# 2025-12-01 14:08:53.111 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1548 bytes
# 2025-12-01 14:08:53.114 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 318953 bytes
# 2025-12-01 14:08:53.121 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1549 bytes
# 2025-12-01 14:08:53.132 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319169 bytes
# 2025-12-01 14:08:53.140 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1547 bytes
# 2025-12-01 14:08:53.143 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 318953 bytes
# 2025-12-01 14:08:53.147 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1548 bytes
# 2025-12-01 14:08:53.151 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319249 bytes
# 2025-12-01 14:08:53.156 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1549 bytes
# 2025-12-01 14:08:53.159 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319249 bytes
# 2025-12-01 14:08:53.162 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1548 bytes
# 2025-12-01 14:08:53.169 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319169 bytes
# 2025-12-01 14:08:53.172 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1548 bytes
# 2025-12-01 14:08:53.177 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319249 bytes
# 2025-12-01 14:08:53.189 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1547 bytes
# 2025-12-01 14:08:53.194 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319105 bytes
# 2025-12-01 14:08:53.200 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1548 bytes
# 2025-12-01 14:08:53.205 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319249 bytes
# 2025-12-01 14:08:53.234 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1548 bytes
# 2025-12-01 14:08:53.236 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319105 bytes
# 2025-12-01 14:08:53.260 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1546 bytes
# 2025-12-01 14:08:53.265 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319041 bytes
# 2025-12-01 14:08:53.271 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1548 bytes
# 2025-12-01 14:08:53.273 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319249 bytes
# 2025-12-01 14:08:53.280 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1549 bytes
# 2025-12-01 14:08:53.288 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319105 bytes
# 2025-12-01 14:08:53.291 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1547 bytes
# 2025-12-01 14:08:53.294 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319105 bytes
# 2025-12-01 14:08:53.301 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1548 bytes
# 2025-12-01 14:08:53.312 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319249 bytes
# 2025-12-01 14:08:53.321 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1549 bytes
# 2025-12-01 14:08:53.336 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319249 bytes
# 2025-12-01 14:08:53.341 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1546 bytes
# 2025-12-01 14:08:53.343 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319249 bytes
# 2025-12-01 14:08:53.347 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1549 bytes
# 2025-12-01 14:08:53.351 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319169 bytes
# 2025-12-01 14:08:53.356 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1547 bytes
# 2025-12-01 14:08:53.359 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319249 bytes
# 2025-12-01 14:08:53.363 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1549 bytes
# 2025-12-01 14:08:53.374 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319249 bytes
# 2025-12-01 14:08:53.378 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1547 bytes
# 2025-12-01 14:08:53.380 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319249 bytes
# 2025-12-01 14:08:53.469 | INFO     | afml.cache.cache_monitoring:_get_function_cache_size:487 - Cache size for afml.production.model_development.compute_sample_weights_time_decay: 15.60 MB (103 files)
# 2025-12-01 14:08:53.471 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:444 - Looking for cache in: C:\Users\JoeN\AppData\Local\afml\afml\Cache\joblib_cache
# 2025-12-01 14:08:53.474 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:459 - Searching for patterns: ['afml_production_model_development_train_model_with_cv', 'train_model_with_cv']
# 2025-12-01 14:08:53.758 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: func_code.py - 1384 bytes
# 2025-12-01 14:08:53.764 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 8100 bytes
# 2025-12-01 14:08:53.777 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 393657 bytes
# 2025-12-01 14:08:53.787 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 8100 bytes
# 2025-12-01 14:08:53.803 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 393657 bytes
# 2025-12-01 14:08:53.806 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 8100 bytes
# 2025-12-01 14:08:53.808 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 392697 bytes
# 2025-12-01 14:08:53.813 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 8101 bytes
# 2025-12-01 14:08:53.818 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 397017 bytes
# 2025-12-01 14:08:53.823 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 8100 bytes
# 2025-12-01 14:08:53.825 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 395737 bytes
# 2025-12-01 14:08:53.829 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 8100 bytes
# 2025-12-01 14:08:53.837 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 397337 bytes
# 2025-12-01 14:08:53.847 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 8101 bytes
# 2025-12-01 14:08:53.852 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 392537 bytes
# 2025-12-01 14:08:53.856 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 8100 bytes
# 2025-12-01 14:08:53.858 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 395097 bytes
# 2025-12-01 14:08:53.867 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 8099 bytes
# 2025-12-01 14:08:53.871 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 398297 bytes
# 2025-12-01 14:08:53.906 | INFO     | afml.cache.cache_monitoring:_get_function_cache_size:487 - Cache size for afml.production.model_development.train_model_with_cv: 3.46 MB (19 files)
# ======================================================================
# CACHE HEALTH REPORT
# ======================================================================
#
# Overall Statistics:
#   Total Functions:     6
#   Total Calls:         250
#   Overall Hit Rate:    80.4%
#   Total Cache Size:    87.41 MB
#
# Top Performers (by hit rate):
#   1. load_and_prepare_training_data: 100.0% (50 calls)
#   2. create_feature_engineering_pipeline: 100.0% (50 calls)
#   3. create_bollinger_features: 100.0% (1 calls)
#   4. generate_events_triple_barrier: 100.0% (50 calls)
#   5. compute_sample_weights_time_decay: 100.0% (50 calls)
#
# Worst Performers (by hit rate):
#   1. create_feature_engineering_pipeline: 100.0% (50 calls)
#   2. create_bollinger_features: 100.0% (1 calls)
#   3. generate_events_triple_barrier: 100.0% (50 calls)
#   4. compute_sample_weights_time_decay: 100.0% (50 calls)
#   5. train_model_with_cv: 0.0% (49 calls)
#
# Recommendations:
#   1. Functions with low hit rate: train_model_with_cv. Review cache key generation for these functions.
#
# ======================================================================

# %%
pprint(get_cache_size_info(), sort_dicts=False)
# Out:
# {'base': {'size_bytes': 695752560, 'size_mb': 663.52, 'file_count': 597},
#  'joblib': {'size_bytes': 344528483, 'size_mb': 328.57, 'file_count': 68},
#  'numba': {'size_bytes': 6217168, 'size_mb': 5.93, 'file_count': 164},
#  'backtest': {'size_bytes': 0, 'size_mb': 0.0, 'file_count': 0}}

# %%
# Detailed analysis of cache patterns
from afml.cache.cache_monitoring import analyze_cache_patterns

analyze_cache_patterns()
# Out:
# 19:59:50 | DEBUG    | Looking for cache in: C:\Users\JoeN\AppData\Local\afml\afml\Cache\joblib_cache
# 19:59:50 | DEBUG    | Searching for patterns: ['__main___load_data', 'load_data']
# 19:59:50 | DEBUG    | Found matching cache file: func_code.py - 662 bytes
# 19:59:50 | DEBUG    | Found matching cache file: metadata.json - 1014 bytes
# 19:59:50 | DEBUG    | Found matching cache file: output.pkl - 9083888 bytes
# 19:59:50 | DEBUG    | Found matching cache file: metadata.json - 1165 bytes
# 19:59:50 | DEBUG    | Found matching cache file: output.pkl - 4437488 bytes
# 19:59:50 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:50 | DEBUG    | Found matching cache file: output.pkl - 9083888 bytes
# 19:59:50 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:50 | DEBUG    | Found matching cache file: output.pkl - 17560608 bytes
# 19:59:50 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:50 | DEBUG    | Found matching cache file: output.pkl - 22166416 bytes
# 19:59:50 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:50 | DEBUG    | Found matching cache file: output.pkl - 29266560 bytes
# 19:59:50 | DEBUG    | Found matching cache file: metadata.json - 1166 bytes
# 19:59:50 | DEBUG    | Found matching cache file: output.pkl - 6056448 bytes
# 19:59:50 | DEBUG    | Found matching cache file: metadata.json - 1015 bytes
# 19:59:50 | DEBUG    | Found matching cache file: output.pkl - 9083888 bytes
# 19:59:50 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:50 | DEBUG    | Found matching cache file: output.pkl - 6056448 bytes
# 19:59:50 | DEBUG    | Found matching cache file: metadata.json - 1017 bytes
# 19:59:50 | DEBUG    | Found matching cache file: output.pkl - 6056448 bytes
# 19:59:50 | DEBUG    | Found matching cache file: metadata.json - 1015 bytes
# 19:59:50 | DEBUG    | Found matching cache file: output.pkl - 9083888 bytes
# 19:59:50 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:50 | DEBUG    | Found matching cache file: output.pkl - 17560608 bytes
# 19:59:50 | DEBUG    | Found matching cache file: metadata.json - 1017 bytes
# 19:59:50 | DEBUG    | Found matching cache file: output.pkl - 29266560 bytes
# 19:59:50 | DEBUG    | Found matching cache file: metadata.json - 1015 bytes
# 19:59:50 | DEBUG    | Found matching cache file: output.pkl - 6056448 bytes
# 19:59:50 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:50 | DEBUG    | Found matching cache file: output.pkl - 22166416 bytes
# 19:59:50 | DEBUG    | Found matching cache file: metadata.json - 1014 bytes
# 19:59:50 | DEBUG    | Found matching cache file: output.pkl - 9083888 bytes
# 19:59:50 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:50 | DEBUG    | Found matching cache file: output.pkl - 4437488 bytes
# 19:59:50 | DEBUG    | Found matching cache file: metadata.json - 1014 bytes
# 19:59:50 | DEBUG    | Found matching cache file: output.pkl - 11089328 bytes
# 19:59:50 | DEBUG    | Found matching cache file: metadata.json - 1015 bytes
# 19:59:50 | DEBUG    | Found matching cache file: output.pkl - 11089328 bytes
# 19:59:50 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:50 | DEBUG    | Found matching cache file: output.pkl - 4437488 bytes
# 19:59:50 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:50 | DEBUG    | Found matching cache file: output.pkl - 29266560 bytes
# 19:59:50 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:50 | DEBUG    | Found matching cache file: output.pkl - 4437488 bytes
# 19:59:50 | DEBUG    | Found matching cache file: metadata.json - 1014 bytes
# 19:59:50 | DEBUG    | Found matching cache file: output.pkl - 3634576 bytes
# 19:59:50 | DEBUG    | Found matching cache file: metadata.json - 1015 bytes
# 19:59:50 | DEBUG    | Found matching cache file: output.pkl - 3634576 bytes
# 19:59:50 | DEBUG    | Found matching cache file: metadata.json - 1166 bytes
# 19:59:50 | DEBUG    | Found matching cache file: output.pkl - 4437488 bytes
# 19:59:51 | DEBUG    | Found matching cache file: metadata.json - 1165 bytes
# 19:59:51 | DEBUG    | Found matching cache file: output.pkl - 6056448 bytes
# 19:59:51 | DEBUG    | Found matching cache file: func_code.py - 537 bytes
# 19:59:51 | DEBUG    | Found matching cache file: metadata.json - 1015 bytes
# 19:59:51 | DEBUG    | Found matching cache file: output.pkl - 9083888 bytes
# 19:59:51 | DEBUG    | Found matching cache file: metadata.json - 1015 bytes
# 19:59:51 | DEBUG    | Found matching cache file: output.pkl - 9083888 bytes
# 19:59:51 | INFO     | Cache size for __main__.load_data: 298.30 MB (58 files)
# 19:59:51 | DEBUG    | Looking for cache in: C:\Users\JoeN\AppData\Local\afml\afml\Cache\joblib_cache
# 19:59:51 | DEBUG    | Searching for patterns: ['afml_strategies_bollinger_features_create_bollinger_features', 'create_bollinger_features']
# 19:59:51 | DEBUG    | Found matching cache file: metadata.json - 1581 bytes
# 19:59:51 | DEBUG    | Found matching cache file: output.pkl - 31733899 bytes
# 19:59:51 | INFO     | Cache size for afml.strategies.bollinger_features.create_bollinger_features: 30.27 MB (2 files)
# 19:59:51 | DEBUG    | Looking for cache in: C:\Users\JoeN\AppData\Local\afml\afml\Cache\joblib_cache
# 19:59:51 | DEBUG    | Searching for patterns: ['afml_cross_validation_cross_validation_analyze_cross_val_scores', 'analyze_cross_val_scores']
# 19:59:51 | DEBUG    | No cache files found for afml.cross_validation.cross_validation.analyze_cross_val_scores
# 19:59:51 | DEBUG    | Looking for cache in: C:\Users\JoeN\AppData\Local\afml\afml\Cache\joblib_cache
# 19:59:51 | DEBUG    | Searching for patterns: ['__main___train_rf', 'train_rf']
# 19:59:51 | DEBUG    | No cache files found for __main__.train_rf
# {'high_miss_rate_functions': [{'function': '__main__.load_data',
#    'hit_rate': 0.16666666666666666,
#    'calls': 24},
#   {'function': 'afml.cross_validation.cross_validation.analyze_cross_val_scores',
#    'hit_rate': 0.21875,
#    'calls': 32},
#   {'function': '__main__.train_rf',
#    'hit_rate': 0.2222222222222222,
#    'calls': 18}],
#  'unused_caches': [],
#  'large_caches': [{'function': '__main__.load_data',
#    'size_mb': 298.2985153198242,
#    'hit_rate': 0.16666666666666666}],
#  'frequently_accessed': [],
#  'optimization_candidates': []}

# %%
from afml.cache import diagnose_cache_issues

# Run diagnostics
diagnose_cache_issues()
# Out:
# ================================================================================
# CACHE DIAGNOSTICS REPORT
# ================================================================================
#
# 1. BASIC STATS:
#    Tracked functions: 4
#    Total calls: 82
#    Overall hit rate: 25.6%
#
# 2. CACHE EFFICIENCY:
# 19:59:51 | DEBUG    | Looking for cache in: C:\Users\JoeN\AppData\Local\afml\afml\Cache\joblib_cache
# 19:59:51 | DEBUG    | Searching for patterns: ['__main___load_data', 'load_data']
# 19:59:51 | DEBUG    | Found matching cache file: func_code.py - 662 bytes
# 19:59:51 | DEBUG    | Found matching cache file: metadata.json - 1014 bytes
# 19:59:51 | DEBUG    | Found matching cache file: output.pkl - 9083888 bytes
# 19:59:51 | DEBUG    | Found matching cache file: metadata.json - 1165 bytes
# 19:59:51 | DEBUG    | Found matching cache file: output.pkl - 4437488 bytes
# 19:59:51 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:51 | DEBUG    | Found matching cache file: output.pkl - 9083888 bytes
# 19:59:51 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:51 | DEBUG    | Found matching cache file: output.pkl - 17560608 bytes
# 19:59:51 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:51 | DEBUG    | Found matching cache file: output.pkl - 22166416 bytes
# 19:59:51 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:51 | DEBUG    | Found matching cache file: output.pkl - 29266560 bytes
# 19:59:51 | DEBUG    | Found matching cache file: metadata.json - 1166 bytes
# 19:59:51 | DEBUG    | Found matching cache file: output.pkl - 6056448 bytes
# 19:59:51 | DEBUG    | Found matching cache file: metadata.json - 1015 bytes
# 19:59:51 | DEBUG    | Found matching cache file: output.pkl - 9083888 bytes
# 19:59:51 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:51 | DEBUG    | Found matching cache file: output.pkl - 6056448 bytes
# 19:59:51 | DEBUG    | Found matching cache file: metadata.json - 1017 bytes
# 19:59:51 | DEBUG    | Found matching cache file: output.pkl - 6056448 bytes
# 19:59:51 | DEBUG    | Found matching cache file: metadata.json - 1015 bytes
# 19:59:51 | DEBUG    | Found matching cache file: output.pkl - 9083888 bytes
# 19:59:51 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:51 | DEBUG    | Found matching cache file: output.pkl - 17560608 bytes
# 19:59:51 | DEBUG    | Found matching cache file: metadata.json - 1017 bytes
# 19:59:51 | DEBUG    | Found matching cache file: output.pkl - 29266560 bytes
# 19:59:51 | DEBUG    | Found matching cache file: metadata.json - 1015 bytes
# 19:59:51 | DEBUG    | Found matching cache file: output.pkl - 6056448 bytes
# 19:59:51 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:51 | DEBUG    | Found matching cache file: output.pkl - 22166416 bytes
# 19:59:51 | DEBUG    | Found matching cache file: metadata.json - 1014 bytes
# 19:59:51 | DEBUG    | Found matching cache file: output.pkl - 9083888 bytes
# 19:59:51 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:51 | DEBUG    | Found matching cache file: output.pkl - 4437488 bytes
# 19:59:51 | DEBUG    | Found matching cache file: metadata.json - 1014 bytes
# 19:59:51 | DEBUG    | Found matching cache file: output.pkl - 11089328 bytes
# 19:59:51 | DEBUG    | Found matching cache file: metadata.json - 1015 bytes
# 19:59:51 | DEBUG    | Found matching cache file: output.pkl - 11089328 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 4437488 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 29266560 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 4437488 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1014 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 3634576 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1015 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 3634576 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1166 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 4437488 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1165 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 6056448 bytes
# 19:59:52 | DEBUG    | Found matching cache file: func_code.py - 537 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1015 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 9083888 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1015 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 9083888 bytes
# 19:59:52 | INFO     | Cache size for __main__.load_data: 298.30 MB (58 files)
# 19:59:52 | DEBUG    | Looking for cache in: C:\Users\JoeN\AppData\Local\afml\afml\Cache\joblib_cache
# 19:59:52 | DEBUG    | Searching for patterns: ['afml_strategies_bollinger_features_create_bollinger_features', 'create_bollinger_features']
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1581 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 31733899 bytes
# 19:59:52 | INFO     | Cache size for afml.strategies.bollinger_features.create_bollinger_features: 30.27 MB (2 files)
# 19:59:52 | DEBUG    | Looking for cache in: C:\Users\JoeN\AppData\Local\afml\afml\Cache\joblib_cache
# 19:59:52 | DEBUG    | Searching for patterns: ['afml_cross_validation_cross_validation_analyze_cross_val_scores', 'analyze_cross_val_scores']
# 19:59:52 | DEBUG    | No cache files found for afml.cross_validation.cross_validation.analyze_cross_val_scores
# 19:59:52 | DEBUG    | Looking for cache in: C:\Users\JoeN\AppData\Local\afml\afml\Cache\joblib_cache
# 19:59:52 | DEBUG    | Searching for patterns: ['__main___train_rf', 'train_rf']
# 19:59:52 | DEBUG    | No cache files found for __main__.train_rf
#    Functions with issues:
#    - 3 functions with <50% hit rate
#
# 3. CACHE SIZES:
#    base: 663.52 MB (597 files)
#    joblib: 328.57 MB (68 files)
#    numba: 5.93 MB (164 files)
#    backtest: 0.00 MB (0 files)
#
# 4. MONITOR STATUS:
# 19:59:52 | DEBUG    | Looking for cache in: C:\Users\JoeN\AppData\Local\afml\afml\Cache\joblib_cache
# 19:59:52 | DEBUG    | Searching for patterns: ['__main___load_data', 'load_data']
# 19:59:52 | DEBUG    | Found matching cache file: func_code.py - 662 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1014 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 9083888 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1165 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 4437488 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 9083888 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 17560608 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 22166416 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 29266560 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1166 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 6056448 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1015 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 9083888 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 6056448 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1017 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 6056448 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1015 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 9083888 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 17560608 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1017 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 29266560 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1015 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 6056448 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 22166416 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1014 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 9083888 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 4437488 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1014 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 11089328 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1015 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 11089328 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 4437488 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 29266560 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 4437488 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1014 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 3634576 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1015 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 3634576 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1166 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 4437488 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1165 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 6056448 bytes
# 19:59:52 | DEBUG    | Found matching cache file: func_code.py - 537 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1015 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 9083888 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1015 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 9083888 bytes
# 19:59:52 | INFO     | Cache size for __main__.load_data: 298.30 MB (58 files)
# 19:59:52 | DEBUG    | Looking for cache in: C:\Users\JoeN\AppData\Local\afml\afml\Cache\joblib_cache
# 19:59:52 | DEBUG    | Searching for patterns: ['afml_strategies_bollinger_features_create_bollinger_features', 'create_bollinger_features']
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1581 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 31733899 bytes
# 19:59:53 | INFO     | Cache size for afml.strategies.bollinger_features.create_bollinger_features: 30.27 MB (2 files)
# 19:59:53 | DEBUG    | Looking for cache in: C:\Users\JoeN\AppData\Local\afml\afml\Cache\joblib_cache
# 19:59:53 | DEBUG    | Searching for patterns: ['afml_cross_validation_cross_validation_analyze_cross_val_scores', 'analyze_cross_val_scores']
# 19:59:53 | DEBUG    | No cache files found for afml.cross_validation.cross_validation.analyze_cross_val_scores
# 19:59:53 | DEBUG    | Looking for cache in: C:\Users\JoeN\AppData\Local\afml\afml\Cache\joblib_cache
# 19:59:53 | DEBUG    | Searching for patterns: ['__main___train_rf', 'train_rf']
# 19:59:53 | DEBUG    | No cache files found for __main__.train_rf
#    Monitor tracking: 4 functions
#    Functions with cache files: 2
#    Functions with timing data: 0
#
# ================================================================================
